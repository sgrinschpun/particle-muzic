# %%
# %load_ext autoreload
# %autoreload 2

# %%
from particle2 import Particle, ParticleDT
import pypdt

# %%
import pypdt
tbl = pypdt.ParticleDataTable()
part_dict = {}
for p in tbl:
    part_dict[p.name]= p.id

# %%
part_dict
# Out:
# {'B(2)*(5747)+': 525,
#  'B(2)*(5747)-': -525,
#  'B(2)*(5747)0': 515,
#  'B(c)+': 541,
#  'B(c)-': -541,
#  'B(s)*0': 533,
#  'B(s)0': 531,
#  'B(s2)*(5840)0': 535,
#  'B*+': 523,
#  'B*-': -523,
#  'B*0': 513,
#  'B+': 521,
#  'B-': -521,
#  'B0': 511,
#  'D(0)*(2400)+': 10411,
#  'D(0)*(2400)-': -10411,
#  'D(0)*(2400)0': 10421,
#  'D(1)(2420)0': 10423,
#  'D(2)*(2460)+': 415,
#  'D(2)*(2460)-': -415,
#  'D(2)*(2460)0': 425,
#  'D(s)*+': 433,
#  'D(s)*-': -433,
#  'D(s)+': 431,
#  'D(s)-': -431,
#  'D(s0)*(2317)+': 10431,
#  'D(s0)*(2317)-': -10431,
#  'D(s1)(2460)+': 20433,
#  'D(s1)(2460)-': -20433,
#  'D(s1)(2536)+': 10433,
#  'D(s1)(2536)-': -10433,
#  'D(s2)*(2573)+': 435,
#  'D(s2)*(2573)-': -435,
#  'D*(2007)0': 423,
#  'D*(2010)+': 413,
#  'D*(2010)-': -413,
#  'D+': 411,
#  'D-': -411,
#  'D0': 421,
#  'Delta(1232)+': 2214,
#  'Delta(1232)++': 2224,
#  'Delta(1232)-': 1114,
#  'Delta(1232)--': -2224,
#  'Delta(1232)0': 2114,
#  'Delta(1600)+': 32214,
#  'Delta(1600)++': 32224,
#  'Delta(1600)-': 31114,
#  'Delta(1600)--': -32224,
#  'Delta(1600)0': 32114,
#  'Delta(1620)+': 2122,
#  'Delta(1620)++': 2222,
#  'Delta(1620)-': 1112,
#  'Delta(1620)--': -2222,
#  'Delta(1620)0': 1212,
#  'Delta(1700)+': 12214,
#  'Delta(1700)++': 12224,
#  'Delta(1700)-': 11114,
#  'Delta(1700)--': -12224,
#  'Delta(1700)0': 12114,
#  'Delta(1905)+': 2126,
#  'Delta(1905)++': 2226,
#  'Delta(1905)-': 1116,
#  'Delta(1905)--': -2226,
#  'Delta(1905)0': 1216,
#  'Delta(1910)+': 22122,
#  'Delta(1910)++': 22222,
#  'Delta(1910)-': 21112,
#  'Delta(1910)--': -22222,
#  'Delta(1910)0': 21212,
#  'Delta(1920)+': 22214,
#  'Delta(1920)++': 22224,
#  'Delta(1920)-': 21114,
#  'Delta(1920)--': -22224,
#  'Delta(1920)0': 22114,
#  'Delta(1930)+': 12126,
#  'Delta(1930)++': 12226,
#  'Delta(1930)-': 11116,
#  'Delta(1930)--': -12226,
#  'Delta(1930)0': 11216,
#  'Delta(1950)+': 2218,
#  'Delta(1950)++': 2228,
#  'Delta(1950)-': 1118,
#  'Delta(1950)--': -2228,
#  'Delta(1950)0': 2118,
#  'H0': 25,
#  'J/psi(1S)0': 443,
#  'K(0)*(1430)+': 10321,
#  'K(0)*(1430)-': -10321,
#  'K(0)*(1430)0': 10311,
#  'K(1)(1270)+': 10323,
#  'K(1)(1270)-': -10323,
#  'K(1)(1270)0': 10313,
#  'K(1)(1400)+': 20323,
#  'K(1)(1400)-': -20323,
#  'K(1)(1400)0': 20313,
#  'K(2)(1770)+': 10325,
#  'K(2)(1770)-': -10325,
#  'K(2)(1770)0': 10315,
#  'K(2)(1820)+': 20325,
#  'K(2)(1820)-': -20325,
#  'K(2)(1820)0': 20315,
#  'K(2)*(1430)+': 325,
#  'K(2)*(1430)-': -325,
#  'K(2)*(1430)0': 315,
#  'K(3)*(1780)+': 327,
#  'K(3)*(1780)-': -327,
#  'K(3)*(1780)0': 317,
#  'K(4)*(2045)+': 329,
#  'K(4)*(2045)-': -329,
#  'K(4)*(2045)0': 319,
#  'K(L)0': 130,
#  'K(S)0': 310,
#  'K*(1410)+': 100323,
#  'K*(1410)-': -100323,
#  'K*(1410)0': 100313,
#  'K*(1680)+': 30323,
#  'K*(1680)-': -30323,
#  'K*(1680)0': 30313,
#  'K*(892)+': 323,
#  'K*(892)-': -323,
#  'K*(892)0': 313,
#  'K+': 321,
#  'K-': -321,
#  'K0': 311,
#  'Lambda(1405)0': 13122,
#  'Lambda(1520)0': 3124,
#  'Lambda(1600)0': 23122,
#  'Lambda(1670)0': 33122,
#  'Lambda(1690)0': 13124,
#  'Lambda(1800)0': 43122,
#  'Lambda(1810)0': 53122,
#  'Lambda(1820)0': 3126,
#  'Lambda(1830)0': 13126,
#  'Lambda(1890)0': 23124,
#  'Lambda(2100)0': 3128,
#  'Lambda(2110)0': 23126,
#  'Lambda(b)0': 5122,
#  'Lambda(c)(2595)+': 14122,
#  'Lambda(c)(2595)-': -14122,
#  'Lambda(c)(2625)+': 104122,
#  'Lambda(c)(2625)-': -104122,
#  'Lambda(c)(2880)+': 204126,
#  'Lambda(c)(2880)-': -204126,
#  'Lambda(c)+': 4122,
#  'Lambda(c)-': -4122,
#  'Lambda0': 3122,
#  'N(1440)+': 12212,
#  'N(1440)-': -12212,
#  'N(1440)0': 12112,
#  'N(1520)+': 2124,
#  'N(1520)-': -2124,
#  'N(1520)0': 1214,
#  'N(1535)+': 22212,
#  'N(1535)-': -22212,
#  'N(1535)0': 22112,
#  'N(1650)+': 32212,
#  'N(1650)-': -32212,
#  'N(1650)0': 32112,
#  'N(1675)+': 2216,
#  'N(1675)-': -2216,
#  'N(1675)0': 2116,
#  'N(1680)+': 12216,
#  'N(1680)-': -12216,
#  'N(1680)0': 12116,
#  'N(1700)+': 22124,
#  'N(1700)-': -22124,
#  'N(1700)0': 21214,
#  'N(1710)+': 42212,
#  'N(1710)-': -42212,
#  'N(1710)0': 42112,
#  'N(1720)+': 32124,
#  'N(1720)-': -32124,
#  'N(1720)0': 31214,
#  'N(2190)+': 2128,
#  'N(2190)-': -2128,
#  'N(2190)0': 1218,
#  'Omega(2250)+': -203338,
#  'Omega(2250)-': 203338,
#  'Omega(b)+': -5332,
#  'Omega(b)-': 5332,
#  'Omega(c)(2770)0': 4334,
#  'Omega(c)0': 4332,
#  'Omega+': -3334,
#  'Omega-': 3334,
#  'Sigma(1385)+': 3224,
#  'Sigma(1385)-': 3114,
#  'Sigma(1385)0': 3214,
#  'Sigma(1660)+': 13222,
#  'Sigma(1660)-': 13112,
#  'Sigma(1660)0': 13212,
#  'Sigma(1670)+': 13224,
#  'Sigma(1670)-': 13114,
#  'Sigma(1670)0': 13214,
#  'Sigma(1750)+': 23222,
#  'Sigma(1750)-': 23112,
#  'Sigma(1750)0': 23212,
#  'Sigma(1775)+': 3226,
#  'Sigma(1775)-': 3116,
#  'Sigma(1775)0': 3216,
#  'Sigma(1915)+': 13226,
#  'Sigma(1915)-': 13116,
#  'Sigma(1915)0': 13216,
#  'Sigma(1940)+': 23224,
#  'Sigma(1940)-': 23114,
#  'Sigma(1940)0': 23214,
#  'Sigma(2030)+': 3228,
#  'Sigma(2030)-': 3118,
#  'Sigma(2030)0': 3218,
#  'Sigma(b)*+': 5224,
#  'Sigma(b)*-': 5114,
#  'Sigma(b)+': 5222,
#  'Sigma(b)-': 5112,
#  'Sigma(c)(2455)+': 4212,
#  'Sigma(c)(2455)++': 4222,
#  'Sigma(c)(2455)-': -4212,
#  'Sigma(c)(2455)--': -4222,
#  'Sigma(c)(2455)0': 4112,
#  'Sigma(c)(2520)+': 4214,
#  'Sigma(c)(2520)++': 4224,
#  'Sigma(c)(2520)-': -4214,
#  'Sigma(c)(2520)--': -4224,
#  'Sigma(c)(2520)0': 4114,
#  'Sigma+': 3222,
#  'Sigma-': 3112,
#  'Sigma0': 3212,
#  'Upsilon(10860)0': 9000553,
#  'Upsilon(11020)0': 9010553,
#  'Upsilon(1D)0': 30553,
#  'Upsilon(1S)0': 553,
#  'Upsilon(2S)0': 100553,
#  'Upsilon(3S)0': 200553,
#  'Upsilon(4S)0': 300553,
#  'W+': 24,
#  'W-': -24,
#  'Xi(1530)+': -3314,
#  'Xi(1530)-': 3314,
#  'Xi(1530)0': 3324,
#  'Xi(1690)+': -203312,
#  'Xi(1690)-': 203312,
#  'Xi(1690)0': 203322,
#  'Xi(1820)+': -13314,
#  'Xi(1820)-': 13314,
#  'Xi(1820)0': 13324,
#  'Xi(1950)+': -103316,
#  'Xi(1950)-': 103316,
#  'Xi(1950)0': 103326,
#  'Xi(2030)+': -203316,
#  'Xi(2030)-': 203316,
#  'Xi(2030)0': 203326,
#  'Xi(b)+': -5132,
#  'Xi(b)-': 5132,
#  'Xi(b)0': 5232,
#  "Xi(c)'+": 4322,
#  "Xi(c)'-": -4322,
#  "Xi(c)'0": 4312,
#  'Xi(c)(2645)+': 4324,
#  'Xi(c)(2645)-': -4324,
#  'Xi(c)(2645)0': 4314,
#  'Xi(c)(2790)+': 104324,
#  'Xi(c)(2790)-': -104324,
#  'Xi(c)(2790)0': 104314,
#  'Xi(c)(2815)+': 104322,
#  'Xi(c)(2815)-': -104322,
#  'Xi(c)(2815)0': 104312,
#  'Xi(c)+': 4232,
#  'Xi(c)-': -4232,
#  'Xi(c)0': 4132,
#  'Xi+': -3312,
#  'Xi-': 3312,
#  'Xi0': 3322,
#  'Z0': 23,
#  'a(0)(1450)+': 10211,
#  'a(0)(1450)-': -10211,
#  'a(0)(1450)0': 10111,
#  'a(0)(980)+': 9000211,
#  'a(0)(980)-': -9000211,
#  'a(0)(980)0': 9000111,
#  'a(1)(1260)+': 20213,
#  'a(1)(1260)-': -20213,
#  'a(1)(1260)0': 20113,
#  'a(2)(1320)+': 215,
#  'a(2)(1320)-': -215,
#  'a(2)(1320)0': 115,
#  'a(4)(2040)+': 219,
#  'a(4)(2040)-': -219,
#  'a(4)(2040)0': 119,
#  'b(1)(1235)+': 10213,
#  'b(1)(1235)-': -10213,
#  'b(1)(1235)0': 10113,
#  'bbar': -5,
#  'cbar': -4,
#  'chi(b0)(1P)0': 10551,
#  'chi(b0)(2P)0': 110551,
#  'chi(b1)(1P)0': 20553,
#  'chi(b1)(2P)0': 120553,
#  'chi(b2)(1P)0': 555,
#  'chi(b2)(2P)0': 100555,
#  'chi(c0)(1P)0': 10441,
#  'chi(c1)(1P)0': 20443,
#  'chi(c2)(1P)0': 445,
#  'chi(c2)(2P)0': 100445,
#  'dbar': -1,
#  'e+': -11,
#  'e-': 11,
#  "eta'(958)0": 331,
#  'eta(1295)0': 100221,
#  'eta(1405)0': 9020221,
#  'eta(1475)0': 100331,
#  'eta(2)(1645)0': 10225,
#  'eta(c)(1S)0': 441,
#  'eta(c)(2S)0': 100441,
#  'eta0': 221,
#  'f(0)(1370)0': 10221,
#  'f(0)(1500)0': 9030221,
#  'f(0)(1710)0': 10331,
#  'f(0)(500)0': 9000221,
#  'f(0)(980)0': 9010221,
#  'f(1)(1285)0': 20223,
#  'f(1)(1420)0': 20333,
#  "f(2)'(1525)0": 335,
#  'f(2)(1270)0': 225,
#  'f(2)(1950)0': 9050225,
#  'f(2)(2010)0': 9060225,
#  'f(2)(2300)0': 9080225,
#  'f(2)(2340)0': 9090225,
#  'f(4)(2050)0': 229,
#  'g0': 21,
#  'gamma0': 22,
#  'h(1)(1170)0': 10223,
#  'h(b)(1P)0': 10553,
#  'h(c)(1P)0': 10443,
#  'mu+': -13,
#  'mu-': 13,
#  'n0': 2112,
#  'nu_e': 12,
#  'nu_mu': 14,
#  'nu_tau': 16,
#  'nubar_e': -12,
#  'nubar_mu': -14,
#  'nubar_tau': -16,
#  'omega(1420)0': 100223,
#  'omega(1650)0': 30223,
#  'omega(3)(1670)0': 227,
#  'omega(782)0': 223,
#  'p+': 2212,
#  'p-': -2212,
#  'phi(1020)0': 333,
#  'phi(1680)0': 100333,
#  'phi(3)(1850)0': 337,
#  'pi(1)(1400)+': 9000213,
#  'pi(1)(1400)-': -9000213,
#  'pi(1)(1400)0': 9000113,
#  'pi(1)(1600)+': 9010213,
#  'pi(1)(1600)-': -9010213,
#  'pi(1)(1600)0': 9010113,
#  'pi(1300)+': 100211,
#  'pi(1300)-': -100211,
#  'pi(1300)0': 100111,
#  'pi(1800)+': 9010211,
#  'pi(1800)-': -9010211,
#  'pi(1800)0': 9010111,
#  'pi(2)(1670)+': 10215,
#  'pi(2)(1670)-': -10215,
#  'pi(2)(1670)0': 10115,
#  'pi+': 211,
#  'pi-': -211,
#  'pi0': 111,
#  'psi(2S)0': 100443,
#  'psi(3770)0': 30443,
#  'psi(4040)0': 9000443,
#  'psi(4160)0': 9010443,
#  'psi(4415)0': 9020443,
#  'rho(1450)+': 100213,
#  'rho(1450)-': -100213,
#  'rho(1450)0': 100113,
#  'rho(1700)+': 30213,
#  'rho(1700)-': -30213,
#  'rho(1700)0': 30113,
#  'rho(3)(1690)+': 217,
#  'rho(3)(1690)-': -217,
#  'rho(3)(1690)0': 117,
#  'rho(770)+': 213,
#  'rho(770)-': -213,
#  'rho(770)0': 113,
#  'sbar': -3,
#  'tau+': -15,
#  'tau-': 15,
#  'tbar': -6,
#  'ubar': -2}

# %%
nu_e = ParticleDT('nu_e')

# %%
nu_e.charge
# Out:
# 0.0

# %%
ParticleDT('e-').charge
# Out:
# -1.0

# %%
from ParticleDataTool import ParticleDataTool as pdt
pythia = pdt.PYTHIAParticleData(file_path='ParticleData.ppl', use_cache=True)
pythia.name(23)
# Out:
# 'Z0'

# %%
pypdt.get(1)
# Out:
# dbar: ID=1, m=0.0047 GeV, 3*q=-1

# %%
part_dict = {}
for p in tbl:
    part_dict[p.name]= p.id

# %%
part_dict
# Out:
# {'B(2)*(5747)+': 525,
#  'B(2)*(5747)-': -525,
#  'B(2)*(5747)0': 515,
#  'B(c)+': 541,
#  'B(c)-': -541,
#  'B(s)*0': 533,
#  'B(s)0': 531,
#  'B(s2)*(5840)0': 535,
#  'B*+': 523,
#  'B*-': -523,
#  'B*0': 513,
#  'B+': 521,
#  'B-': -521,
#  'B0': 511,
#  'D(0)*(2400)+': 10411,
#  'D(0)*(2400)-': -10411,
#  'D(0)*(2400)0': 10421,
#  'D(1)(2420)0': 10423,
#  'D(2)*(2460)+': 415,
#  'D(2)*(2460)-': -415,
#  'D(2)*(2460)0': 425,
#  'D(s)*+': 433,
#  'D(s)*-': -433,
#  'D(s)+': 431,
#  'D(s)-': -431,
#  'D(s0)*(2317)+': 10431,
#  'D(s0)*(2317)-': -10431,
#  'D(s1)(2460)+': 20433,
#  'D(s1)(2460)-': -20433,
#  'D(s1)(2536)+': 10433,
#  'D(s1)(2536)-': -10433,
#  'D(s2)*(2573)+': 435,
#  'D(s2)*(2573)-': -435,
#  'D*(2007)0': 423,
#  'D*(2010)+': 413,
#  'D*(2010)-': -413,
#  'D+': 411,
#  'D-': -411,
#  'D0': 421,
#  'Delta(1232)+': 2214,
#  'Delta(1232)++': 2224,
#  'Delta(1232)-': 1114,
#  'Delta(1232)--': -2224,
#  'Delta(1232)0': 2114,
#  'Delta(1600)+': 32214,
#  'Delta(1600)++': 32224,
#  'Delta(1600)-': 31114,
#  'Delta(1600)--': -32224,
#  'Delta(1600)0': 32114,
#  'Delta(1620)+': 2122,
#  'Delta(1620)++': 2222,
#  'Delta(1620)-': 1112,
#  'Delta(1620)--': -2222,
#  'Delta(1620)0': 1212,
#  'Delta(1700)+': 12214,
#  'Delta(1700)++': 12224,
#  'Delta(1700)-': 11114,
#  'Delta(1700)--': -12224,
#  'Delta(1700)0': 12114,
#  'Delta(1905)+': 2126,
#  'Delta(1905)++': 2226,
#  'Delta(1905)-': 1116,
#  'Delta(1905)--': -2226,
#  'Delta(1905)0': 1216,
#  'Delta(1910)+': 22122,
#  'Delta(1910)++': 22222,
#  'Delta(1910)-': 21112,
#  'Delta(1910)--': -22222,
#  'Delta(1910)0': 21212,
#  'Delta(1920)+': 22214,
#  'Delta(1920)++': 22224,
#  'Delta(1920)-': 21114,
#  'Delta(1920)--': -22224,
#  'Delta(1920)0': 22114,
#  'Delta(1930)+': 12126,
#  'Delta(1930)++': 12226,
#  'Delta(1930)-': 11116,
#  'Delta(1930)--': -12226,
#  'Delta(1930)0': 11216,
#  'Delta(1950)+': 2218,
#  'Delta(1950)++': 2228,
#  'Delta(1950)-': 1118,
#  'Delta(1950)--': -2228,
#  'Delta(1950)0': 2118,
#  'H0': 25,
#  'J/psi(1S)0': 443,
#  'K(0)*(1430)+': 10321,
#  'K(0)*(1430)-': -10321,
#  'K(0)*(1430)0': 10311,
#  'K(1)(1270)+': 10323,
#  'K(1)(1270)-': -10323,
#  'K(1)(1270)0': 10313,
#  'K(1)(1400)+': 20323,
#  'K(1)(1400)-': -20323,
#  'K(1)(1400)0': 20313,
#  'K(2)(1770)+': 10325,
#  'K(2)(1770)-': -10325,
#  'K(2)(1770)0': 10315,
#  'K(2)(1820)+': 20325,
#  'K(2)(1820)-': -20325,
#  'K(2)(1820)0': 20315,
#  'K(2)*(1430)+': 325,
#  'K(2)*(1430)-': -325,
#  'K(2)*(1430)0': 315,
#  'K(3)*(1780)+': 327,
#  'K(3)*(1780)-': -327,
#  'K(3)*(1780)0': 317,
#  'K(4)*(2045)+': 329,
#  'K(4)*(2045)-': -329,
#  'K(4)*(2045)0': 319,
#  'K(L)0': 130,
#  'K(S)0': 310,
#  'K*(1410)+': 100323,
#  'K*(1410)-': -100323,
#  'K*(1410)0': 100313,
#  'K*(1680)+': 30323,
#  'K*(1680)-': -30323,
#  'K*(1680)0': 30313,
#  'K*(892)+': 323,
#  'K*(892)-': -323,
#  'K*(892)0': 313,
#  'K+': 321,
#  'K-': -321,
#  'K0': 311,
#  'Lambda(1405)0': 13122,
#  'Lambda(1520)0': 3124,
#  'Lambda(1600)0': 23122,
#  'Lambda(1670)0': 33122,
#  'Lambda(1690)0': 13124,
#  'Lambda(1800)0': 43122,
#  'Lambda(1810)0': 53122,
#  'Lambda(1820)0': 3126,
#  'Lambda(1830)0': 13126,
#  'Lambda(1890)0': 23124,
#  'Lambda(2100)0': 3128,
#  'Lambda(2110)0': 23126,
#  'Lambda(b)0': 5122,
#  'Lambda(c)(2595)+': 14122,
#  'Lambda(c)(2595)-': -14122,
#  'Lambda(c)(2625)+': 104122,
#  'Lambda(c)(2625)-': -104122,
#  'Lambda(c)(2880)+': 204126,
#  'Lambda(c)(2880)-': -204126,
#  'Lambda(c)+': 4122,
#  'Lambda(c)-': -4122,
#  'Lambda0': 3122,
#  'N(1440)+': 12212,
#  'N(1440)-': -12212,
#  'N(1440)0': 12112,
#  'N(1520)+': 2124,
#  'N(1520)-': -2124,
#  'N(1520)0': 1214,
#  'N(1535)+': 22212,
#  'N(1535)-': -22212,
#  'N(1535)0': 22112,
#  'N(1650)+': 32212,
#  'N(1650)-': -32212,
#  'N(1650)0': 32112,
#  'N(1675)+': 2216,
#  'N(1675)-': -2216,
#  'N(1675)0': 2116,
#  'N(1680)+': 12216,
#  'N(1680)-': -12216,
#  'N(1680)0': 12116,
#  'N(1700)+': 22124,
#  'N(1700)-': -22124,
#  'N(1700)0': 21214,
#  'N(1710)+': 42212,
#  'N(1710)-': -42212,
#  'N(1710)0': 42112,
#  'N(1720)+': 32124,
#  'N(1720)-': -32124,
#  'N(1720)0': 31214,
#  'N(2190)+': 2128,
#  'N(2190)-': -2128,
#  'N(2190)0': 1218,
#  'Omega(2250)+': -203338,
#  'Omega(2250)-': 203338,
#  'Omega(b)+': -5332,
#  'Omega(b)-': 5332,
#  'Omega(c)(2770)0': 4334,
#  'Omega(c)0': 4332,
#  'Omega+': -3334,
#  'Omega-': 3334,
#  'Sigma(1385)+': 3224,
#  'Sigma(1385)-': 3114,
#  'Sigma(1385)0': 3214,
#  'Sigma(1660)+': 13222,
#  'Sigma(1660)-': 13112,
#  'Sigma(1660)0': 13212,
#  'Sigma(1670)+': 13224,
#  'Sigma(1670)-': 13114,
#  'Sigma(1670)0': 13214,
#  'Sigma(1750)+': 23222,
#  'Sigma(1750)-': 23112,
#  'Sigma(1750)0': 23212,
#  'Sigma(1775)+': 3226,
#  'Sigma(1775)-': 3116,
#  'Sigma(1775)0': 3216,
#  'Sigma(1915)+': 13226,
#  'Sigma(1915)-': 13116,
#  'Sigma(1915)0': 13216,
#  'Sigma(1940)+': 23224,
#  'Sigma(1940)-': 23114,
#  'Sigma(1940)0': 23214,
#  'Sigma(2030)+': 3228,
#  'Sigma(2030)-': 3118,
#  'Sigma(2030)0': 3218,
#  'Sigma(b)*+': 5224,
#  'Sigma(b)*-': 5114,
#  'Sigma(b)+': 5222,
#  'Sigma(b)-': 5112,
#  'Sigma(c)(2455)+': 4212,
#  'Sigma(c)(2455)++': 4222,
#  'Sigma(c)(2455)-': -4212,
#  'Sigma(c)(2455)--': -4222,
#  'Sigma(c)(2455)0': 4112,
#  'Sigma(c)(2520)+': 4214,
#  'Sigma(c)(2520)++': 4224,
#  'Sigma(c)(2520)-': -4214,
#  'Sigma(c)(2520)--': -4224,
#  'Sigma(c)(2520)0': 4114,
#  'Sigma+': 3222,
#  'Sigma-': 3112,
#  'Sigma0': 3212,
#  'Upsilon(10860)0': 9000553,
#  'Upsilon(11020)0': 9010553,
#  'Upsilon(1D)0': 30553,
#  'Upsilon(1S)0': 553,
#  'Upsilon(2S)0': 100553,
#  'Upsilon(3S)0': 200553,
#  'Upsilon(4S)0': 300553,
#  'W+': 24,
#  'W-': -24,
#  'Xi(1530)+': -3314,
#  'Xi(1530)-': 3314,
#  'Xi(1530)0': 3324,
#  'Xi(1690)+': -203312,
#  'Xi(1690)-': 203312,
#  'Xi(1690)0': 203322,
#  'Xi(1820)+': -13314,
#  'Xi(1820)-': 13314,
#  'Xi(1820)0': 13324,
#  'Xi(1950)+': -103316,
#  'Xi(1950)-': 103316,
#  'Xi(1950)0': 103326,
#  'Xi(2030)+': -203316,
#  'Xi(2030)-': 203316,
#  'Xi(2030)0': 203326,
#  'Xi(b)+': -5132,
#  'Xi(b)-': 5132,
#  'Xi(b)0': 5232,
#  "Xi(c)'+": 4322,
#  "Xi(c)'-": -4322,
#  "Xi(c)'0": 4312,
#  'Xi(c)(2645)+': 4324,
#  'Xi(c)(2645)-': -4324,
#  'Xi(c)(2645)0': 4314,
#  'Xi(c)(2790)+': 104324,
#  'Xi(c)(2790)-': -104324,
#  'Xi(c)(2790)0': 104314,
#  'Xi(c)(2815)+': 104322,
#  'Xi(c)(2815)-': -104322,
#  'Xi(c)(2815)0': 104312,
#  'Xi(c)+': 4232,
#  'Xi(c)-': -4232,
#  'Xi(c)0': 4132,
#  'Xi+': -3312,
#  'Xi-': 3312,
#  'Xi0': 3322,
#  'Z0': 23,
#  'a(0)(1450)+': 10211,
#  'a(0)(1450)-': -10211,
#  'a(0)(1450)0': 10111,
#  'a(0)(980)+': 9000211,
#  'a(0)(980)-': -9000211,
#  'a(0)(980)0': 9000111,
#  'a(1)(1260)+': 20213,
#  'a(1)(1260)-': -20213,
#  'a(1)(1260)0': 20113,
#  'a(2)(1320)+': 215,
#  'a(2)(1320)-': -215,
#  'a(2)(1320)0': 115,
#  'a(4)(2040)+': 219,
#  'a(4)(2040)-': -219,
#  'a(4)(2040)0': 119,
#  'b(1)(1235)+': 10213,
#  'b(1)(1235)-': -10213,
#  'b(1)(1235)0': 10113,
#  'bbar': -5,
#  'cbar': -4,
#  'chi(b0)(1P)0': 10551,
#  'chi(b0)(2P)0': 110551,
#  'chi(b1)(1P)0': 20553,
#  'chi(b1)(2P)0': 120553,
#  'chi(b2)(1P)0': 555,
#  'chi(b2)(2P)0': 100555,
#  'chi(c0)(1P)0': 10441,
#  'chi(c1)(1P)0': 20443,
#  'chi(c2)(1P)0': 445,
#  'chi(c2)(2P)0': 100445,
#  'dbar': -1,
#  'e+': -11,
#  'e-': 11,
#  "eta'(958)0": 331,
#  'eta(1295)0': 100221,
#  'eta(1405)0': 9020221,
#  'eta(1475)0': 100331,
#  'eta(2)(1645)0': 10225,
#  'eta(c)(1S)0': 441,
#  'eta(c)(2S)0': 100441,
#  'eta0': 221,
#  'f(0)(1370)0': 10221,
#  'f(0)(1500)0': 9030221,
#  'f(0)(1710)0': 10331,
#  'f(0)(500)0': 9000221,
#  'f(0)(980)0': 9010221,
#  'f(1)(1285)0': 20223,
#  'f(1)(1420)0': 20333,
#  "f(2)'(1525)0": 335,
#  'f(2)(1270)0': 225,
#  'f(2)(1950)0': 9050225,
#  'f(2)(2010)0': 9060225,
#  'f(2)(2300)0': 9080225,
#  'f(2)(2340)0': 9090225,
#  'f(4)(2050)0': 229,
#  'g0': 21,
#  'gamma0': 22,
#  'h(1)(1170)0': 10223,
#  'h(b)(1P)0': 10553,
#  'h(c)(1P)0': 10443,
#  'mu+': -13,
#  'mu-': 13,
#  'n0': 2112,
#  'nu_e': 12,
#  'nu_mu': 14,
#  'nu_tau': 16,
#  'nubar_e': -12,
#  'nubar_mu': -14,
#  'nubar_tau': -16,
#  'omega(1420)0': 100223,
#  'omega(1650)0': 30223,
#  'omega(3)(1670)0': 227,
#  'omega(782)0': 223,
#  'p+': 2212,
#  'p-': -2212,
#  'phi(1020)0': 333,
#  'phi(1680)0': 100333,
#  'phi(3)(1850)0': 337,
#  'pi(1)(1400)+': 9000213,
#  'pi(1)(1400)-': -9000213,
#  'pi(1)(1400)0': 9000113,
#  'pi(1)(1600)+': 9010213,
#  'pi(1)(1600)-': -9010213,
#  'pi(1)(1600)0': 9010113,
#  'pi(1300)+': 100211,
#  'pi(1300)-': -100211,
#  'pi(1300)0': 100111,
#  'pi(1800)+': 9010211,
#  'pi(1800)-': -9010211,
#  'pi(1800)0': 9010111,
#  'pi(2)(1670)+': 10215,
#  'pi(2)(1670)-': -10215,
#  'pi(2)(1670)0': 10115,
#  'pi+': 211,
#  'pi-': -211,
#  'pi0': 111,
#  'psi(2S)0': 100443,
#  'psi(3770)0': 30443,
#  'psi(4040)0': 9000443,
#  'psi(4160)0': 9010443,
#  'psi(4415)0': 9020443,
#  'rho(1450)+': 100213,
#  'rho(1450)-': -100213,
#  'rho(1450)0': 100113,
#  'rho(1700)+': 30213,
#  'rho(1700)-': -30213,
#  'rho(1700)0': 30113,
#  'rho(3)(1690)+': 217,
#  'rho(3)(1690)-': -217,
#  'rho(3)(1690)0': 117,
#  'rho(770)+': 213,
#  'rho(770)-': -213,
#  'rho(770)0': 113,
#  'sbar': -3,
#  'tau+': -15,
#  'tau-': 15,
#  'tbar': -6,
#  'ubar': -2}

# %%
quarks={'u':-2, 'd':-1, 'c':-4, 's': -3, 'b':-5, 't':-6 }

# %%
quarks.keys()
# Out:
# ['c', 'b', 'd', 's', 'u', 't']

# %%
print quarks.keys()[quarks.values().index(-2)]
# Out:
# u

# %%
quarks.values()
# Out:
# [-4, -5, -1, -3, -2, -6]

# %%
Z0.decay
# Out:
# ['tau-', 'tau+']
