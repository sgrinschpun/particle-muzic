# %%
# %load_ext autoreload
# %autoreload 2

# %%
from __future__ import print_function
import sys
python_path = '/Users/sgrinschpun/code/particle-muzic/python'
sys.path.append(python_path)

import math, random

from phenomena.particles.particle import ParticleDT
from phenomena.particles.particle_boosted import ParticleBoosted
from phenomena.particles.kinematics.decay import LABcalc
from phenomena.particles.kinematics.parameters import boostParams

# %%
Kplus= ParticleBoosted("K+", theta=0, p=1)

# %%
Kplus.decayvalues
# Out:
# [{'name': 'pi+', 'p': 0.31976367307424586, 'theta': -0.5849102719642639},
#  {'name': 'pi0', 'p': 0.7543443801565897, 'theta': 0.23623460284520484}]

# %%
Kplus.decay_time
# Out:
# 0.8678334072590035

# %%
Kplus2.decay_time
# Out:
# 3.8912854139783057

# %%
Kplus2.decay
# Out:
# ['pi+', 'pi0', 'pi0']

# %%
ParticleDT.get_list_all_particles()
# Out:
# {
#  "A0(H_3)": {
#   "ctau": 5.84637838129351e-15,
#   "charge": 0.0,
#   "pdg_id": 36,
#   "mass": 300.0
#  },
#  "B*+": {
#   "ctau": NaN,
#   "charge": 1.0,
#   "pdg_id": 523,
#   "mass": 5.3252
#  },
#  "B*-": {
#   "ctau": NaN,
#   "charge": -1.0,
#   "pdg_id": -523,
#   "mass": 5.3252
#  },
#  "B*0": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 513,
#   "mass": 5.3252
#  },
#  "B*_0+": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": 1.0,
#   "pdg_id": 10521,
#   "mass": 5.68
#  },
#  "B*_0-": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": -1.0,
#   "pdg_id": -10521,
#   "mass": 5.68
#  },
#  "B*_00": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": 0.0,
#   "pdg_id": 10511,
#   "mass": 5.68
#  },
#  "B*_0bar0": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": -0.0,
#   "pdg_id": -10511,
#   "mass": 5.68
#  },
#  "B*_0c+": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": 1.0,
#   "pdg_id": 10541,
#   "mass": 7.25
#  },
#  "B*_0c-": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": -1.0,
#   "pdg_id": -10541,
#   "mass": 7.25
#  },
#  "B*_0s0": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": 0.0,
#   "pdg_id": 10531,
#   "mass": 5.92
#  },
#  "B*_0sbar0": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": -0.0,
#   "pdg_id": -10531,
#   "mass": 5.92
#  },
#  "B*_1+": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": 1.0,
#   "pdg_id": 20523,
#   "mass": 5.78
#  },
#  "B*_1-": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": -1.0,
#   "pdg_id": -20523,
#   "mass": 5.78
#  },
#  "B*_10": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": 0.0,
#   "pdg_id": 20513,
#   "mass": 5.78
#  },
#  "B*_1bar0": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": -0.0,
#   "pdg_id": -20513,
#   "mass": 5.78
#  },
#  "B*_1c+": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": 1.0,
#   "pdg_id": 20543,
#   "mass": 7.3
#  },
#  "B*_1c-": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": -1.0,
#   "pdg_id": -20543,
#   "mass": 7.3
#  },
#  "B*_1s0": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": 0.0,
#   "pdg_id": 20533,
#   "mass": 6.02
#  },
#  "B*_1sbar0": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": -0.0,
#   "pdg_id": -20533,
#   "mass": 6.02
#  },
#  "B*_2+": {
#   "ctau": 8.579433179366023e-13,
#   "charge": 1.0,
#   "pdg_id": 525,
#   "mass": 5.743
#  },
#  "B*_2-": {
#   "ctau": 8.579433179366023e-13,
#   "charge": -1.0,
#   "pdg_id": -525,
#   "mass": 5.743
#  },
#  "B*_20": {
#   "ctau": 8.579433179366023e-13,
#   "charge": 0.0,
#   "pdg_id": 515,
#   "mass": 5.743
#  },
#  "B*_2bar0": {
#   "ctau": 8.579433179366023e-13,
#   "charge": -0.0,
#   "pdg_id": -515,
#   "mass": 5.743
#  },
#  "B*_2c+": {
#   "ctau": 9.866348156270929e-13,
#   "charge": 1.0,
#   "pdg_id": 545,
#   "mass": 7.35
#  },
#  "B*_2c-": {
#   "ctau": 9.866348156270929e-13,
#   "charge": -1.0,
#   "pdg_id": -545,
#   "mass": 7.35
#  },
#  "B*_2s0": {
#   "ctau": 9.866348156270929e-13,
#   "charge": 0.0,
#   "pdg_id": 535,
#   "mass": 5.8397
#  },
#  "B*_2sbar0": {
#   "ctau": 9.866348156270929e-13,
#   "charge": -0.0,
#   "pdg_id": -535,
#   "mass": 5.8397
#  },
#  "B*_c+": {
#   "ctau": NaN,
#   "charge": 1.0,
#   "pdg_id": 543,
#   "mass": 6.34
#  },
#  "B*_c-": {
#   "ctau": NaN,
#   "charge": -1.0,
#   "pdg_id": -543,
#   "mass": 6.34
#  },
#  "B*_s0": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 533,
#   "mass": 5.4154
#  },
#  "B*_sbar0": {
#   "ctau": NaN,
#   "charge": -0.0,
#   "pdg_id": -533,
#   "mass": 5.4154
#  },
#  "B*bar0": {
#   "ctau": NaN,
#   "charge": -0.0,
#   "pdg_id": -513,
#   "mass": 5.3252
#  },
#  "B+": {
#   "ctau": 0.04911,
#   "charge": 1.0,
#   "pdg_id": 521,
#   "mass": 5.27925
#  },
#  "B-": {
#   "ctau": 0.04911,
#   "charge": -1.0,
#   "pdg_id": -521,
#   "mass": 5.27925
#  },
#  "B0": {
#   "ctau": 0.04587,
#   "charge": 0.0,
#   "pdg_id": 511,
#   "mass": 5.27958
#  },
#  "B_1+": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": 1.0,
#   "pdg_id": 10523,
#   "mass": 5.73
#  },
#  "B_1-": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": -1.0,
#   "pdg_id": -10523,
#   "mass": 5.73
#  },
#  "B_10": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": 0.0,
#   "pdg_id": 10513,
#   "mass": 5.73
#  },
#  "B_1bar0": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": -0.0,
#   "pdg_id": -10513,
#   "mass": 5.73
#  },
#  "B_1c+": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": 1.0,
#   "pdg_id": 10543,
#   "mass": 7.3
#  },
#  "B_1c-": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": -1.0,
#   "pdg_id": -10543,
#   "mass": 7.3
#  },
#  "B_1s0": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": 0.0,
#   "pdg_id": 10533,
#   "mass": 5.97
#  },
#  "B_1sbar0": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": -0.0,
#   "pdg_id": -10533,
#   "mass": 5.97
#  },
#  "B_c+": {
#   "ctau": 0.013800000000000002,
#   "charge": 1.0,
#   "pdg_id": 541,
#   "mass": 6.277
#  },
#  "B_c-": {
#   "ctau": 0.013800000000000002,
#   "charge": -1.0,
#   "pdg_id": -541,
#   "mass": 6.277
#  },
#  "B_s0": {
#   "ctau": 0.0439,
#   "charge": 0.0,
#   "pdg_id": 531,
#   "mass": 5.36677
#  },
#  "B_sbar0": {
#   "ctau": 0.0439,
#   "charge": -0.0,
#   "pdg_id": -531,
#   "mass": 5.36677
#  },
#  "Bbar0": {
#   "ctau": 0.04587,
#   "charge": -0.0,
#   "pdg_id": -511,
#   "mass": 5.27958
#  },
#  "BlackHole": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 40,
#   "mass": 0.0
#  },
#  "Bv": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": -0.3333333333333333,
#   "pdg_id": 4900005,
#   "mass": 400.0
#  },
#  "Bvbar": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": 0.3333333333333333,
#   "pdg_id": -4900005,
#   "mass": 400.0
#  },
#  "Cv": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": 0.6666666666666666,
#   "pdg_id": 4900004,
#   "mass": 400.0
#  },
#  "Cvbar": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": -0.6666666666666666,
#   "pdg_id": -4900004,
#   "mass": 400.0
#  },
#  "D*+": {
#   "ctau": 2.0554891992231095e-09,
#   "charge": 1.0,
#   "pdg_id": 413,
#   "mass": 2.01028
#  },
#  "D*-": {
#   "ctau": 2.0554891992231095e-09,
#   "charge": -1.0,
#   "pdg_id": -413,
#   "mass": 2.01028
#  },
#  "D*0": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 423,
#   "mass": 2.00698
#  },
#  "D*_0+": {
#   "ctau": 7.308406041682169e-14,
#   "charge": 1.0,
#   "pdg_id": 10411,
#   "mass": 2.318
#  },
#  "D*_0-": {
#   "ctau": 7.308406041682169e-14,
#   "charge": -1.0,
#   "pdg_id": -10411,
#   "mass": 2.318
#  },
#  "D*_00": {
#   "ctau": 7.308406041682169e-14,
#   "charge": 0.0,
#   "pdg_id": 10421,
#   "mass": 2.318
#  },
#  "D*_0bar0": {
#   "ctau": 7.308406041682169e-14,
#   "charge": -0.0,
#   "pdg_id": -10421,
#   "mass": 2.318
#  },
#  "D*_0s+": {
#   "ctau": 9.866348156270929e-13,
#   "charge": 1.0,
#   "pdg_id": 10431,
#   "mass": 2.3178
#  },
#  "D*_0s-": {
#   "ctau": 9.866348156270929e-13,
#   "charge": -1.0,
#   "pdg_id": -10431,
#   "mass": 2.3178
#  },
#  "D*_1+": {
#   "ctau": 5.138722998057775e-14,
#   "charge": 1.0,
#   "pdg_id": 20413,
#   "mass": 2.427
#  },
#  "D*_1-": {
#   "ctau": 5.138722998057775e-14,
#   "charge": -1.0,
#   "pdg_id": -20413,
#   "mass": 2.427
#  },
#  "D*_10": {
#   "ctau": 5.138722998057775e-14,
#   "charge": 0.0,
#   "pdg_id": 20423,
#   "mass": 2.427
#  },
#  "D*_1bar0": {
#   "ctau": 5.138722998057775e-14,
#   "charge": -0.0,
#   "pdg_id": -20423,
#   "mass": 2.427
#  },
#  "D*_1s+": {
#   "ctau": 6.577565437513952e-13,
#   "charge": 1.0,
#   "pdg_id": 20433,
#   "mass": 2.4596
#  },
#  "D*_1s-": {
#   "ctau": 6.577565437513952e-13,
#   "charge": -1.0,
#   "pdg_id": -20433,
#   "mass": 2.4596
#  },
#  "D*_2(2460)+": {
#   "ctau": 5.333161165551853e-13,
#   "charge": 1.0,
#   "pdg_id": 415,
#   "mass": 2.4644
#  },
#  "D*_2(2460)-": {
#   "ctau": 5.333161165551853e-13,
#   "charge": -1.0,
#   "pdg_id": -415,
#   "mass": 2.4644
#  },
#  "D*_2(2460)0": {
#   "ctau": 4.027080880110583e-13,
#   "charge": 0.0,
#   "pdg_id": 425,
#   "mass": 2.4626
#  },
#  "D*_2(2460)bar0": {
#   "ctau": 4.027080880110583e-13,
#   "charge": -0.0,
#   "pdg_id": -425,
#   "mass": 2.4626
#  },
#  "D*_2s(2573)+": {
#   "ctau": 1.1607468419142268e-12,
#   "charge": 1.0,
#   "pdg_id": 435,
#   "mass": 2.5719
#  },
#  "D*_2s(2573)-": {
#   "ctau": 1.1607468419142268e-12,
#   "charge": -1.0,
#   "pdg_id": -435,
#   "mass": 2.5719
#  },
#  "D*_s+": {
#   "ctau": 0.0,
#   "charge": 1.0,
#   "pdg_id": 433,
#   "mass": 2.1123
#  },
#  "D*_s-": {
#   "ctau": 0.0,
#   "charge": -1.0,
#   "pdg_id": -433,
#   "mass": 2.1123
#  },
#  "D*bar0": {
#   "ctau": NaN,
#   "charge": -0.0,
#   "pdg_id": -423,
#   "mass": 2.00698
#  },
#  "D+": {
#   "ctau": 0.031180000000000003,
#   "charge": 1.0,
#   "pdg_id": 411,
#   "mass": 1.86962
#  },
#  "D-": {
#   "ctau": 0.031180000000000003,
#   "charge": -1.0,
#   "pdg_id": -411,
#   "mass": 1.86962
#  },
#  "D0": {
#   "ctau": 0.01229,
#   "charge": 0.0,
#   "pdg_id": 421,
#   "mass": 1.86486
#  },
#  "D_1+": {
#   "ctau": 9.866348156270929e-13,
#   "charge": 1.0,
#   "pdg_id": 10413,
#   "mass": 2.424
#  },
#  "D_1-": {
#   "ctau": 9.866348156270929e-13,
#   "charge": -1.0,
#   "pdg_id": -10413,
#   "mass": 2.424
#  },
#  "D_10": {
#   "ctau": 7.281437753705482e-13,
#   "charge": 0.0,
#   "pdg_id": 10423,
#   "mass": 2.4213
#  },
#  "D_1bar0": {
#   "ctau": 7.281437753705482e-13,
#   "charge": -0.0,
#   "pdg_id": -10423,
#   "mass": 2.4213
#  },
#  "D_1s+": {
#   "ctau": NaN,
#   "charge": 1.0,
#   "pdg_id": 10433,
#   "mass": 2.53512
#  },
#  "D_1s-": {
#   "ctau": NaN,
#   "charge": -1.0,
#   "pdg_id": -10433,
#   "mass": 2.53512
#  },
#  "D_s+": {
#   "ctau": 0.014990000000000002,
#   "charge": 1.0,
#   "pdg_id": 431,
#   "mass": 1.96849
#  },
#  "D_s-": {
#   "ctau": 0.014990000000000002,
#   "charge": -1.0,
#   "pdg_id": -431,
#   "mass": 1.96849
#  },
#  "Dbar0": {
#   "ctau": 0.01229,
#   "charge": -0.0,
#   "pdg_id": -421,
#   "mass": 1.86486
#  },
#  "Delta+": {
#   "ctau": 1.6865552403881926e-13,
#   "charge": 1.0,
#   "pdg_id": 2214,
#   "mass": 1.232
#  },
#  "Delta++": {
#   "ctau": 1.6865552403881926e-13,
#   "charge": 2.0,
#   "pdg_id": 2224,
#   "mass": 1.232
#  },
#  "Delta-": {
#   "ctau": 1.6865552403881926e-13,
#   "charge": -1.0,
#   "pdg_id": 1114,
#   "mass": 1.232
#  },
#  "Delta0": {
#   "ctau": 1.6865552403881926e-13,
#   "charge": 0.0,
#   "pdg_id": 2114,
#   "mass": 1.232
#  },
#  "Deltabar+": {
#   "ctau": 1.6865552403881926e-13,
#   "charge": 1.0,
#   "pdg_id": -1114,
#   "mass": 1.232
#  },
#  "Deltabar-": {
#   "ctau": 1.6865552403881926e-13,
#   "charge": -1.0,
#   "pdg_id": -2214,
#   "mass": 1.232
#  },
#  "Deltabar--": {
#   "ctau": 1.6865552403881926e-13,
#   "charge": -2.0,
#   "pdg_id": -2224,
#   "mass": 1.232
#  },
#  "Deltabar0": {
#   "ctau": 1.6865552403881926e-13,
#   "charge": -0.0,
#   "pdg_id": -2114,
#   "mass": 1.232
#  },
#  "Dv": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": -0.3333333333333333,
#   "pdg_id": 4900001,
#   "mass": 400.0
#  },
#  "Dvbar": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": 0.3333333333333333,
#   "pdg_id": -4900001,
#   "mass": 400.0
#  },
#  "Ev": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": -1.0,
#   "pdg_id": 4900011,
#   "mass": 400.0
#  },
#  "Evbar": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": 1.0,
#   "pdg_id": -4900011,
#   "mass": 400.0
#  },
#  "Graviton": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 5000039,
#   "mass": 0.0
#  },
#  "Graviton*": {
#   "ctau": 1.3945368418757496e-13,
#   "charge": 0.0,
#   "pdg_id": 5100039,
#   "mass": 1000.0
#  },
#  "H+": {
#   "ctau": 4.724481901348163e-15,
#   "charge": 1.0,
#   "pdg_id": 37,
#   "mass": 300.0
#  },
#  "H-": {
#   "ctau": 4.724481901348163e-15,
#   "charge": -1.0,
#   "pdg_id": -37,
#   "mass": 300.0
#  },
#  "H0(H_2)": {
#   "ctau": 2.3523734281952805e-15,
#   "charge": 0.0,
#   "pdg_id": 35,
#   "mass": 300.0
#  },
#  "H_L++": {
#   "ctau": 2.2383076387597245e-14,
#   "charge": 2.0,
#   "pdg_id": 9900041,
#   "mass": 200.0
#  },
#  "H_L--": {
#   "ctau": 2.2383076387597245e-14,
#   "charge": -2.0,
#   "pdg_id": -9900041,
#   "mass": 200.0
#  },
#  "H_R++": {
#   "ctau": 2.24232637271643e-14,
#   "charge": 2.0,
#   "pdg_id": 9900042,
#   "mass": 200.0
#  },
#  "H_R--": {
#   "ctau": 2.24232637271643e-14,
#   "charge": -2.0,
#   "pdg_id": -9900042,
#   "mass": 200.0
#  },
#  "J/psi": {
#   "ctau": 2.1925218125046507e-10,
#   "charge": 0.0,
#   "pdg_id": 443,
#   "mass": 3.09692
#  },
#  "J/psi_di": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 9900440,
#   "mass": 0.0
#  },
#  "K*(1680)+": {
#   "ctau": 6.16646759766933e-14,
#   "charge": 1.0,
#   "pdg_id": 30323,
#   "mass": 1.717
#  },
#  "K*(1680)-": {
#   "ctau": 6.16646759766933e-14,
#   "charge": -1.0,
#   "pdg_id": -30323,
#   "mass": 1.717
#  },
#  "K*(1680)0": {
#   "ctau": 6.16646759766933e-14,
#   "charge": 0.0,
#   "pdg_id": 30313,
#   "mass": 1.717
#  },
#  "K*(1680)bar0": {
#   "ctau": 6.16646759766933e-14,
#   "charge": -0.0,
#   "pdg_id": -30313,
#   "mass": 1.717
#  },
#  "K*+": {
#   "ctau": 3.88438903790194e-13,
#   "charge": 1.0,
#   "pdg_id": 323,
#   "mass": 0.89166
#  },
#  "K*-": {
#   "ctau": 3.88438903790194e-13,
#   "charge": -1.0,
#   "pdg_id": -323,
#   "mass": 0.89166
#  },
#  "K*0": {
#   "ctau": 4.051888359864857e-13,
#   "charge": 0.0,
#   "pdg_id": 313,
#   "mass": 0.89594
#  },
#  "K*_0(1430)+": {
#   "ctau": 7.308406041682169e-14,
#   "charge": 1.0,
#   "pdg_id": 10321,
#   "mass": 1.43
#  },
#  "K*_0(1430)-": {
#   "ctau": 7.308406041682169e-14,
#   "charge": -1.0,
#   "pdg_id": -10321,
#   "mass": 1.43
#  },
#  "K*_0(1430)0": {
#   "ctau": 7.308406041682169e-14,
#   "charge": 0.0,
#   "pdg_id": 10311,
#   "mass": 1.43
#  },
#  "K*_0(1430)bar0": {
#   "ctau": 7.308406041682169e-14,
#   "charge": -0.0,
#   "pdg_id": -10311,
#   "mass": 1.43
#  },
#  "K*_2(1430)+": {
#   "ctau": 2.0033194225930813e-13,
#   "charge": 1.0,
#   "pdg_id": 325,
#   "mass": 1.4256
#  },
#  "K*_2(1430)-": {
#   "ctau": 2.0033194225930813e-13,
#   "charge": -1.0,
#   "pdg_id": -325,
#   "mass": 1.4256
#  },
#  "K*_2(1430)0": {
#   "ctau": 1.8103391112423723e-13,
#   "charge": 0.0,
#   "pdg_id": 315,
#   "mass": 1.4324
#  },
#  "K*_2(1430)bar0": {
#   "ctau": 1.8103391112423723e-13,
#   "charge": -0.0,
#   "pdg_id": -315,
#   "mass": 1.4324
#  },
#  "K*bar0": {
#   "ctau": 4.051888359864857e-13,
#   "charge": -0.0,
#   "pdg_id": -313,
#   "mass": 0.89594
#  },
#  "K+": {
#   "ctau": 371.3,
#   "charge": 1.0,
#   "pdg_id": 321,
#   "mass": 0.49368
#  },
#  "K-": {
#   "ctau": 371.3,
#   "charge": -1.0,
#   "pdg_id": -321,
#   "mass": 0.49368
#  },
#  "K0": {
#   "ctau": 0.0,
#   "charge": 0.0,
#   "pdg_id": 311,
#   "mass": 0.49761
#  },
#  "KKgluon*": {
#   "ctau": 1.1607468419142268e-16,
#   "charge": 0.0,
#   "pdg_id": 5100021,
#   "mass": 1000.0
#  },
#  "K_1(1270)+": {
#   "ctau": 2.1925218125046503e-13,
#   "charge": 1.0,
#   "pdg_id": 10323,
#   "mass": 1.272
#  },
#  "K_1(1270)-": {
#   "ctau": 2.1925218125046503e-13,
#   "charge": -1.0,
#   "pdg_id": -10323,
#   "mass": 1.272
#  },
#  "K_1(1270)0": {
#   "ctau": 2.1925218125046503e-13,
#   "charge": 0.0,
#   "pdg_id": 10313,
#   "mass": 1.272
#  },
#  "K_1(1270)bar0": {
#   "ctau": 2.1925218125046503e-13,
#   "charge": -0.0,
#   "pdg_id": -10313,
#   "mass": 1.272
#  },
#  "K_1(1400)+": {
#   "ctau": 1.1340630064679228e-13,
#   "charge": 1.0,
#   "pdg_id": 20323,
#   "mass": 1.403
#  },
#  "K_1(1400)-": {
#   "ctau": 1.1340630064679228e-13,
#   "charge": -1.0,
#   "pdg_id": -20323,
#   "mass": 1.403
#  },
#  "K_1(1400)0": {
#   "ctau": 1.1340630064679228e-13,
#   "charge": 0.0,
#   "pdg_id": 20313,
#   "mass": 1.403
#  },
#  "K_1(1400)bar0": {
#   "ctau": 1.1340630064679228e-13,
#   "charge": -0.0,
#   "pdg_id": -20313,
#   "mass": 1.403
#  },
#  "K_L0": {
#   "ctau": 1533.0,
#   "charge": 0.0,
#   "pdg_id": 130,
#   "mass": 0.49761
#  },
#  "K_S0": {
#   "ctau": 2.6842,
#   "charge": 0.0,
#   "pdg_id": 310,
#   "mass": 0.49761
#  },
#  "Kbar0": {
#   "ctau": 0.0,
#   "charge": -0.0,
#   "pdg_id": -311,
#   "mass": 0.49761
#  },
#  "LQ_ue": {
#   "ctau": 5.038735588719129e-14,
#   "charge": -0.3333333333333333,
#   "pdg_id": 42,
#   "mass": 200.0
#  },
#  "LQ_uebar": {
#   "ctau": 5.038735588719129e-14,
#   "charge": 0.3333333333333333,
#   "pdg_id": -42,
#   "mass": 200.0
#  },
#  "Lambda(1405)0": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": 0.0,
#   "pdg_id": 13122,
#   "mass": 1.4051
#  },
#  "Lambda(1405)bar0": {
#   "ctau": 3.9465392625083707e-13,
#   "charge": -0.0,
#   "pdg_id": -13122,
#   "mass": 1.4051
#  },
#  "Lambda(1520)0": {
#   "ctau": 1.2649164302911446e-12,
#   "charge": 0.0,
#   "pdg_id": 3124,
#   "mass": 1.5195
#  },
#  "Lambda(1520)bar0": {
#   "ctau": 1.2649164302911446e-12,
#   "charge": -0.0,
#   "pdg_id": -3124,
#   "mass": 1.5195
#  },
#  "Lambda(1600)0": {
#   "ctau": 1.3155130875027904e-13,
#   "charge": 0.0,
#   "pdg_id": 23122,
#   "mass": 1.6
#  },
#  "Lambda(1600)bar0": {
#   "ctau": 1.3155130875027904e-13,
#   "charge": -0.0,
#   "pdg_id": -23122,
#   "mass": 1.6
#  },
#  "Lambda(1670)0": {
#   "ctau": 5.637913232154815e-13,
#   "charge": 0.0,
#   "pdg_id": 33122,
#   "mass": 1.67
#  },
#  "Lambda(1670)bar0": {
#   "ctau": 5.637913232154815e-13,
#   "charge": -0.0,
#   "pdg_id": -33122,
#   "mass": 1.67
#  },
#  "Lambda0": {
#   "ctau": 7.890000000000001,
#   "charge": 0.0,
#   "pdg_id": 3122,
#   "mass": 1.11568
#  },
#  "Lambda_b0": {
#   "ctau": 0.0369,
#   "charge": 0.0,
#   "pdg_id": 5122,
#   "mass": 5.6194
#  },
#  "Lambda_bbar0": {
#   "ctau": 0.0369,
#   "charge": -0.0,
#   "pdg_id": -5122,
#   "mass": 5.6194
#  },
#  "Lambda_c(2593)+": {
#   "ctau": 7.589498581746867e-12,
#   "charge": 1.0,
#   "pdg_id": 14122,
#   "mass": 2.59225
#  },
#  "Lambda_c(2593)-": {
#   "ctau": 7.589498581746867e-12,
#   "charge": -1.0,
#   "pdg_id": -14122,
#   "mass": 2.59225
#  },
#  "Lambda_c(2625)+": {
#   "ctau": NaN,
#   "charge": 1.0,
#   "pdg_id": 4124,
#   "mass": 2.6281
#  },
#  "Lambda_c(2625)-": {
#   "ctau": NaN,
#   "charge": -1.0,
#   "pdg_id": -4124,
#   "mass": 2.6281
#  },
#  "Lambda_c+": {
#   "ctau": 0.0059900000000000005,
#   "charge": 1.0,
#   "pdg_id": 4122,
#   "mass": 2.28646
#  },
#  "Lambda_cbar-": {
#   "ctau": 0.0059900000000000005,
#   "charge": -1.0,
#   "pdg_id": -4122,
#   "mass": 2.28646
#  },
#  "Lambdabar0": {
#   "ctau": 7.890000000000001,
#   "charge": -0.0,
#   "pdg_id": -3122,
#   "mass": 1.11568
#  },
#  "MUv": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": -1.0,
#   "pdg_id": 4900013,
#   "mass": 400.0
#  },
#  "MUvbar": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": 1.0,
#   "pdg_id": -4900013,
#   "mass": 400.0
#  },
#  "Omega'_bc0": {
#   "ctau": 0.0364,
#   "charge": 0.0,
#   "pdg_id": 5432,
#   "mass": 7.21101
#  },
#  "Omega'_bcbar0": {
#   "ctau": 0.0364,
#   "charge": -0.0,
#   "pdg_id": -5432,
#   "mass": 7.21101
#  },
#  "Omega*_b-": {
#   "ctau": NaN,
#   "charge": -1.0,
#   "pdg_id": 5334,
#   "mass": 6.13
#  },
#  "Omega*_bb-": {
#   "ctau": 0.0364,
#   "charge": -1.0,
#   "pdg_id": 5534,
#   "mass": 10.61426
#  },
#  "Omega*_bbar+": {
#   "ctau": NaN,
#   "charge": 1.0,
#   "pdg_id": -5334,
#   "mass": 6.13
#  },
#  "Omega*_bbb-": {
#   "ctau": 0.0364,
#   "charge": -1.0,
#   "pdg_id": 5554,
#   "mass": 15.11061
#  },
#  "Omega*_bbbar+": {
#   "ctau": 0.0364,
#   "charge": 1.0,
#   "pdg_id": -5534,
#   "mass": 10.61426
#  },
#  "Omega*_bbbbar+": {
#   "ctau": 0.0364,
#   "charge": 1.0,
#   "pdg_id": -5554,
#   "mass": 15.11061
#  },
#  "Omega*_bbc0": {
#   "ctau": 0.0364,
#   "charge": 0.0,
#   "pdg_id": 5544,
#   "mass": 11.71147
#  },
#  "Omega*_bbcbar0": {
#   "ctau": 0.0364,
#   "charge": -0.0,
#   "pdg_id": -5544,
#   "mass": 11.71147
#  },
#  "Omega*_bc0": {
#   "ctau": 0.0364,
#   "charge": 0.0,
#   "pdg_id": 5434,
#   "mass": 7.219
#  },
#  "Omega*_bcbar0": {
#   "ctau": 0.0364,
#   "charge": -0.0,
#   "pdg_id": -5434,
#   "mass": 7.219
#  },
#  "Omega*_bcc+": {
#   "ctau": 0.0364,
#   "charge": 1.0,
#   "pdg_id": 5444,
#   "mass": 8.31325
#  },
#  "Omega*_bccbar-": {
#   "ctau": 0.0364,
#   "charge": -1.0,
#   "pdg_id": -5444,
#   "mass": 8.31325
#  },
#  "Omega*_c0": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 4334,
#   "mass": 2.7659
#  },
#  "Omega*_cbar0": {
#   "ctau": NaN,
#   "charge": -0.0,
#   "pdg_id": -4334,
#   "mass": 2.7659
#  },
#  "Omega*_cc+": {
#   "ctau": 0.010000000000000002,
#   "charge": 1.0,
#   "pdg_id": 4434,
#   "mass": 3.82466
#  },
#  "Omega*_ccbar-": {
#   "ctau": 0.010000000000000002,
#   "charge": -1.0,
#   "pdg_id": -4434,
#   "mass": 3.82466
#  },
#  "Omega*_ccc++": {
#   "ctau": 0.010000000000000002,
#   "charge": 2.0,
#   "pdg_id": 4444,
#   "mass": 4.91594
#  },
#  "Omega*_cccbar--": {
#   "ctau": 0.010000000000000002,
#   "charge": -2.0,
#   "pdg_id": -4444,
#   "mass": 4.91594
#  },
#  "Omega-": {
#   "ctau": 2.4610000000000003,
#   "charge": -1.0,
#   "pdg_id": 3334,
#   "mass": 1.67245
#  },
#  "Omega_b-": {
#   "ctau": 0.0364,
#   "charge": -1.0,
#   "pdg_id": 5332,
#   "mass": 6.07
#  },
#  "Omega_bb-": {
#   "ctau": 0.0364,
#   "charge": -1.0,
#   "pdg_id": 5532,
#   "mass": 10.60209
#  },
#  "Omega_bbar+": {
#   "ctau": 0.0364,
#   "charge": 1.0,
#   "pdg_id": -5332,
#   "mass": 6.07
#  },
#  "Omega_bbbar+": {
#   "ctau": 0.0364,
#   "charge": 1.0,
#   "pdg_id": -5532,
#   "mass": 10.60209
#  },
#  "Omega_bbc0": {
#   "ctau": 0.0364,
#   "charge": 0.0,
#   "pdg_id": 5542,
#   "mass": 11.70767
#  },
#  "Omega_bbcbar0": {
#   "ctau": 0.0364,
#   "charge": -0.0,
#   "pdg_id": -5542,
#   "mass": 11.70767
#  },
#  "Omega_bc0": {
#   "ctau": 0.0364,
#   "charge": 0.0,
#   "pdg_id": 5342,
#   "mass": 7.19099
#  },
#  "Omega_bcbar0": {
#   "ctau": 0.0364,
#   "charge": -0.0,
#   "pdg_id": -5342,
#   "mass": 7.19099
#  },
#  "Omega_bcc+": {
#   "ctau": 0.0364,
#   "charge": 1.0,
#   "pdg_id": 5442,
#   "mass": 8.30945
#  },
#  "Omega_bccbar-": {
#   "ctau": 0.0364,
#   "charge": -1.0,
#   "pdg_id": -5442,
#   "mass": 8.30945
#  },
#  "Omega_c0": {
#   "ctau": 0.0021000000000000003,
#   "charge": 0.0,
#   "pdg_id": 4332,
#   "mass": 2.6952
#  },
#  "Omega_cbar0": {
#   "ctau": 0.0021000000000000003,
#   "charge": -0.0,
#   "pdg_id": -4332,
#   "mass": 2.6952
#  },
#  "Omega_cc+": {
#   "ctau": 0.010000000000000002,
#   "charge": 1.0,
#   "pdg_id": 4432,
#   "mass": 3.78663
#  },
#  "Omega_ccbar-": {
#   "ctau": 0.010000000000000002,
#   "charge": -1.0,
#   "pdg_id": -4432,
#   "mass": 3.78663
#  },
#  "Omegabar+": {
#   "ctau": 2.4610000000000003,
#   "charge": 1.0,
#   "pdg_id": -3334,
#   "mass": 1.67245
#  },
#  "Pomeron": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 990,
#   "mass": 0.0
#  },
#  "R0": {
#   "ctau": 4.7286595524902595e-17,
#   "charge": 0.0,
#   "pdg_id": 41,
#   "mass": 5000.0
#  },
#  "Rbar0": {
#   "ctau": 4.7286595524902595e-17,
#   "charge": -0.0,
#   "pdg_id": -41,
#   "mass": 5000.0
#  },
#  "Reggeon": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 110,
#   "mass": 0.0
#  },
#  "Sigma*+": {
#   "ctau": 5.481304531261627e-13,
#   "charge": 1.0,
#   "pdg_id": 3224,
#   "mass": 1.3828
#  },
#  "Sigma*-": {
#   "ctau": 5.008298556482704e-13,
#   "charge": -1.0,
#   "pdg_id": 3114,
#   "mass": 1.3872
#  },
#  "Sigma*0": {
#   "ctau": 5.481304531261627e-13,
#   "charge": 0.0,
#   "pdg_id": 3214,
#   "mass": 1.3837
#  },
#  "Sigma*_b+": {
#   "ctau": NaN,
#   "charge": 1.0,
#   "pdg_id": 5224,
#   "mass": 5.8321
#  },
#  "Sigma*_b-": {
#   "ctau": NaN,
#   "charge": -1.0,
#   "pdg_id": 5114,
#   "mass": 5.8351
#  },
#  "Sigma*_b0": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 5214,
#   "mass": 5.81
#  },
#  "Sigma*_bbar+": {
#   "ctau": NaN,
#   "charge": 1.0,
#   "pdg_id": -5114,
#   "mass": 5.8351
#  },
#  "Sigma*_bbar-": {
#   "ctau": NaN,
#   "charge": -1.0,
#   "pdg_id": -5224,
#   "mass": 5.8321
#  },
#  "Sigma*_bbar0": {
#   "ctau": NaN,
#   "charge": -0.0,
#   "pdg_id": -5214,
#   "mass": 5.81
#  },
#  "Sigma*_c+": {
#   "ctau": 1.2730771814543133e-12,
#   "charge": 1.0,
#   "pdg_id": 4214,
#   "mass": 2.5175
#  },
#  "Sigma*_c++": {
#   "ctau": 1.3243420343987821e-12,
#   "charge": 2.0,
#   "pdg_id": 4224,
#   "mass": 2.5179
#  },
#  "Sigma*_c0": {
#   "ctau": 1.3608756077615072e-12,
#   "charge": 0.0,
#   "pdg_id": 4114,
#   "mass": 2.5188
#  },
#  "Sigma*_cbar-": {
#   "ctau": 1.2730771814543133e-12,
#   "charge": -1.0,
#   "pdg_id": -4214,
#   "mass": 2.5175
#  },
#  "Sigma*_cbar--": {
#   "ctau": 1.3243420343987821e-12,
#   "charge": -2.0,
#   "pdg_id": -4224,
#   "mass": 2.5179
#  },
#  "Sigma*_cbar0": {
#   "ctau": 1.3608756077615072e-12,
#   "charge": -0.0,
#   "pdg_id": -4114,
#   "mass": 2.5188
#  },
#  "Sigma*bar+": {
#   "ctau": 5.008298556482704e-13,
#   "charge": 1.0,
#   "pdg_id": -3114,
#   "mass": 1.3872
#  },
#  "Sigma*bar-": {
#   "ctau": 5.481304531261627e-13,
#   "charge": -1.0,
#   "pdg_id": -3224,
#   "mass": 1.3828
#  },
#  "Sigma*bar0": {
#   "ctau": 5.481304531261627e-13,
#   "charge": -0.0,
#   "pdg_id": -3214,
#   "mass": 1.3837
#  },
#  "Sigma+": {
#   "ctau": 2.404,
#   "charge": 1.0,
#   "pdg_id": 3222,
#   "mass": 1.18937
#  },
#  "Sigma-": {
#   "ctau": 4.434,
#   "charge": -1.0,
#   "pdg_id": 3112,
#   "mass": 1.19745
#  },
#  "Sigma0": {
#   "ctau": 2.22e-09,
#   "charge": 0.0,
#   "pdg_id": 3212,
#   "mass": 1.19264
#  },
#  "Sigma_b+": {
#   "ctau": NaN,
#   "charge": 1.0,
#   "pdg_id": 5222,
#   "mass": 5.8113
#  },
#  "Sigma_b-": {
#   "ctau": NaN,
#   "charge": -1.0,
#   "pdg_id": 5112,
#   "mass": 5.8155
#  },
#  "Sigma_b0": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 5212,
#   "mass": 5.8
#  },
#  "Sigma_bbar+": {
#   "ctau": NaN,
#   "charge": 1.0,
#   "pdg_id": -5112,
#   "mass": 5.8155
#  },
#  "Sigma_bbar-": {
#   "ctau": NaN,
#   "charge": -1.0,
#   "pdg_id": -5222,
#   "mass": 5.8113
#  },
#  "Sigma_bbar0": {
#   "ctau": NaN,
#   "charge": -0.0,
#   "pdg_id": -5212,
#   "mass": 5.8
#  },
#  "Sigma_c+": {
#   "ctau": 8.969407414791752e-12,
#   "charge": 1.0,
#   "pdg_id": 4212,
#   "mass": 2.4529
#  },
#  "Sigma_c++": {
#   "ctau": 8.73128155422206e-12,
#   "charge": 2.0,
#   "pdg_id": 4222,
#   "mass": 2.45398
#  },
#  "Sigma_c0": {
#   "ctau": 9.13550755210271e-12,
#   "charge": 0.0,
#   "pdg_id": 4112,
#   "mass": 2.45374
#  },
#  "Sigma_cbar-": {
#   "ctau": 8.969407414791752e-12,
#   "charge": -1.0,
#   "pdg_id": -4212,
#   "mass": 2.4529
#  },
#  "Sigma_cbar--": {
#   "ctau": 8.73128155422206e-12,
#   "charge": -2.0,
#   "pdg_id": -4222,
#   "mass": 2.45398
#  },
#  "Sigma_cbar0": {
#   "ctau": 9.13550755210271e-12,
#   "charge": -0.0,
#   "pdg_id": -4112,
#   "mass": 2.45374
#  },
#  "Sigmabar+": {
#   "ctau": 4.434,
#   "charge": 1.0,
#   "pdg_id": -3112,
#   "mass": 1.19745
#  },
#  "Sigmabar-": {
#   "ctau": 2.404,
#   "charge": -1.0,
#   "pdg_id": -3222,
#   "mass": 1.18937
#  },
#  "Sigmabar0": {
#   "ctau": 2.22e-09,
#   "charge": -0.0,
#   "pdg_id": -3212,
#   "mass": 1.19264
#  },
#  "Sv": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": -0.3333333333333333,
#   "pdg_id": 4900003,
#   "mass": 400.0
#  },
#  "Svbar": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": 0.3333333333333333,
#   "pdg_id": -4900003,
#   "mass": 400.0
#  },
#  "TAUv": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": -1.0,
#   "pdg_id": 4900015,
#   "mass": 400.0
#  },
#  "TAUvbar": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": 1.0,
#   "pdg_id": -4900015,
#   "mass": 400.0
#  },
#  "Tv": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": 0.6666666666666666,
#   "pdg_id": 4900006,
#   "mass": 400.0
#  },
#  "Tvbar": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": -0.6666666666666666,
#   "pdg_id": -4900006,
#   "mass": 400.0
#  },
#  "Upsilon": {
#   "ctau": 3.9465392625083707e-10,
#   "charge": 0.0,
#   "pdg_id": 553,
#   "mass": 9.4603
#  },
#  "Upsilon(2S)": {
#   "ctau": 6.577565437513952e-10,
#   "charge": 0.0,
#   "pdg_id": 100553,
#   "mass": 10.02326
#  },
#  "Uv": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": 0.6666666666666666,
#   "pdg_id": 4900002,
#   "mass": 400.0
#  },
#  "Uvbar": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": -0.6666666666666666,
#   "pdg_id": -4900002,
#   "mass": 400.0
#  },
#  "V8_tc": {
#   "ctau": 1.6006875212057534e-16,
#   "charge": 0.0,
#   "pdg_id": 3100021,
#   "mass": 500.0
#  },
#  "W'+": {
#   "ctau": 1.1843651735306156e-15,
#   "charge": 1.0,
#   "pdg_id": 34,
#   "mass": 500.0
#  },
#  "W'-": {
#   "ctau": 1.1843651735306156e-15,
#   "charge": -1.0,
#   "pdg_id": -34,
#   "mass": 500.0
#  },
#  "W+": {
#   "ctau": 9.46412293167475e-15,
#   "charge": 1.0,
#   "pdg_id": 24,
#   "mass": 80.385
#  },
#  "W-": {
#   "ctau": 9.46412293167475e-15,
#   "charge": -1.0,
#   "pdg_id": -24,
#   "mass": 80.385
#  },
#  "W_R+": {
#   "ctau": 9.072854451639445e-16,
#   "charge": 1.0,
#   "pdg_id": 9900024,
#   "mass": 750.0
#  },
#  "W_R-": {
#   "ctau": 9.072854451639445e-16,
#   "charge": -1.0,
#   "pdg_id": -9900024,
#   "mass": 750.0
#  },
#  "Xi'_b-": {
#   "ctau": NaN,
#   "charge": -1.0,
#   "pdg_id": 5312,
#   "mass": 5.96
#  },
#  "Xi'_b0": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 5322,
#   "mass": 5.96
#  },
#  "Xi'_bbar+": {
#   "ctau": NaN,
#   "charge": 1.0,
#   "pdg_id": -5312,
#   "mass": 5.96
#  },
#  "Xi'_bbar0": {
#   "ctau": NaN,
#   "charge": -0.0,
#   "pdg_id": -5322,
#   "mass": 5.96
#  },
#  "Xi'_bc+": {
#   "ctau": 0.0364,
#   "charge": 1.0,
#   "pdg_id": 5422,
#   "mass": 7.03724
#  },
#  "Xi'_bc0": {
#   "ctau": 0.0364,
#   "charge": 0.0,
#   "pdg_id": 5412,
#   "mass": 7.03724
#  },
#  "Xi'_bcbar-": {
#   "ctau": 0.0364,
#   "charge": -1.0,
#   "pdg_id": -5422,
#   "mass": 7.03724
#  },
#  "Xi'_bcbar0": {
#   "ctau": 0.0364,
#   "charge": -0.0,
#   "pdg_id": -5412,
#   "mass": 7.03724
#  },
#  "Xi'_c+": {
#   "ctau": NaN,
#   "charge": 1.0,
#   "pdg_id": 4322,
#   "mass": 2.5756
#  },
#  "Xi'_c0": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 4312,
#   "mass": 2.5779
#  },
#  "Xi'_cbar-": {
#   "ctau": NaN,
#   "charge": -1.0,
#   "pdg_id": -4322,
#   "mass": 2.5756
#  },
#  "Xi'_cbar0": {
#   "ctau": NaN,
#   "charge": -0.0,
#   "pdg_id": -4312,
#   "mass": 2.5779
#  },
#  "Xi*-": {
#   "ctau": 1.9932016477315006e-12,
#   "charge": -1.0,
#   "pdg_id": 3314,
#   "mass": 1.535
#  },
#  "Xi*0": {
#   "ctau": 2.1684281662133903e-12,
#   "charge": 0.0,
#   "pdg_id": 3324,
#   "mass": 1.5318
#  },
#  "Xi*_b-": {
#   "ctau": NaN,
#   "charge": -1.0,
#   "pdg_id": 5314,
#   "mass": 5.97
#  },
#  "Xi*_b0": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 5324,
#   "mass": 5.97
#  },
#  "Xi*_bb-": {
#   "ctau": 0.0364,
#   "charge": -1.0,
#   "pdg_id": 5514,
#   "mass": 10.44144
#  },
#  "Xi*_bb0": {
#   "ctau": 0.0364,
#   "charge": 0.0,
#   "pdg_id": 5524,
#   "mass": 10.44144
#  },
#  "Xi*_bbar+": {
#   "ctau": NaN,
#   "charge": 1.0,
#   "pdg_id": -5314,
#   "mass": 5.97
#  },
#  "Xi*_bbar0": {
#   "ctau": NaN,
#   "charge": -0.0,
#   "pdg_id": -5324,
#   "mass": 5.97
#  },
#  "Xi*_bbbar+": {
#   "ctau": 0.0364,
#   "charge": 1.0,
#   "pdg_id": -5514,
#   "mass": 10.44144
#  },
#  "Xi*_bbbar0": {
#   "ctau": 0.0364,
#   "charge": -0.0,
#   "pdg_id": -5524,
#   "mass": 10.44144
#  },
#  "Xi*_bc+": {
#   "ctau": 0.0364,
#   "charge": 1.0,
#   "pdg_id": 5424,
#   "mass": 7.0485
#  },
#  "Xi*_bc0": {
#   "ctau": 0.0364,
#   "charge": 0.0,
#   "pdg_id": 5414,
#   "mass": 7.0485
#  },
#  "Xi*_bcbar-": {
#   "ctau": 0.0364,
#   "charge": -1.0,
#   "pdg_id": -5424,
#   "mass": 7.0485
#  },
#  "Xi*_bcbar0": {
#   "ctau": 0.0364,
#   "charge": -0.0,
#   "pdg_id": -5414,
#   "mass": 7.0485
#  },
#  "Xi*_c+": {
#   "ctau": 0.0,
#   "charge": 1.0,
#   "pdg_id": 4324,
#   "mass": 2.6459
#  },
#  "Xi*_c0": {
#   "ctau": 0.0,
#   "charge": 0.0,
#   "pdg_id": 4314,
#   "mass": 2.6459
#  },
#  "Xi*_cbar-": {
#   "ctau": 0.0,
#   "charge": -1.0,
#   "pdg_id": -4324,
#   "mass": 2.6459
#  },
#  "Xi*_cbar0": {
#   "ctau": 0.0,
#   "charge": -0.0,
#   "pdg_id": -4314,
#   "mass": 2.6459
#  },
#  "Xi*_cc+": {
#   "ctau": 0.010000000000000002,
#   "charge": 1.0,
#   "pdg_id": 4414,
#   "mass": 3.65648
#  },
#  "Xi*_cc++": {
#   "ctau": 0.010000000000000002,
#   "charge": 2.0,
#   "pdg_id": 4424,
#   "mass": 3.65648
#  },
#  "Xi*_ccbar-": {
#   "ctau": 0.010000000000000002,
#   "charge": -1.0,
#   "pdg_id": -4414,
#   "mass": 3.65648
#  },
#  "Xi*_ccbar--": {
#   "ctau": 0.010000000000000002,
#   "charge": -2.0,
#   "pdg_id": -4424,
#   "mass": 3.65648
#  },
#  "Xi*bar+": {
#   "ctau": 1.9932016477315006e-12,
#   "charge": 1.0,
#   "pdg_id": -3314,
#   "mass": 1.535
#  },
#  "Xi*bar0": {
#   "ctau": 2.1684281662133903e-12,
#   "charge": -0.0,
#   "pdg_id": -3324,
#   "mass": 1.5318
#  },
#  "Xi-": {
#   "ctau": 4.91,
#   "charge": -1.0,
#   "pdg_id": 3312,
#   "mass": 1.32171
#  },
#  "Xi0": {
#   "ctau": 8.709999999999999,
#   "charge": 0.0,
#   "pdg_id": 3322,
#   "mass": 1.31486
#  },
#  "Xi_b-": {
#   "ctau": 0.0364,
#   "charge": -1.0,
#   "pdg_id": 5132,
#   "mass": 5.7911
#  },
#  "Xi_b0": {
#   "ctau": 0.0364,
#   "charge": 0.0,
#   "pdg_id": 5232,
#   "mass": 5.788
#  },
#  "Xi_bb-": {
#   "ctau": 0.0364,
#   "charge": -1.0,
#   "pdg_id": 5512,
#   "mass": 10.42272
#  },
#  "Xi_bb0": {
#   "ctau": 0.0364,
#   "charge": 0.0,
#   "pdg_id": 5522,
#   "mass": 10.42272
#  },
#  "Xi_bbar+": {
#   "ctau": 0.0364,
#   "charge": 1.0,
#   "pdg_id": -5132,
#   "mass": 5.7911
#  },
#  "Xi_bbar0": {
#   "ctau": 0.0364,
#   "charge": -0.0,
#   "pdg_id": -5232,
#   "mass": 5.788
#  },
#  "Xi_bbbar+": {
#   "ctau": 0.0364,
#   "charge": 1.0,
#   "pdg_id": -5512,
#   "mass": 10.42272
#  },
#  "Xi_bbbar0": {
#   "ctau": 0.0364,
#   "charge": -0.0,
#   "pdg_id": -5522,
#   "mass": 10.42272
#  },
#  "Xi_bc+": {
#   "ctau": 0.0364,
#   "charge": 1.0,
#   "pdg_id": 5242,
#   "mass": 7.00575
#  },
#  "Xi_bc0": {
#   "ctau": 0.0364,
#   "charge": 0.0,
#   "pdg_id": 5142,
#   "mass": 7.00575
#  },
#  "Xi_bcbar-": {
#   "ctau": 0.0364,
#   "charge": -1.0,
#   "pdg_id": -5242,
#   "mass": 7.00575
#  },
#  "Xi_bcbar0": {
#   "ctau": 0.0364,
#   "charge": -0.0,
#   "pdg_id": -5142,
#   "mass": 7.00575
#  },
#  "Xi_c+": {
#   "ctau": 0.013200000000000002,
#   "charge": 1.0,
#   "pdg_id": 4232,
#   "mass": 2.4678
#  },
#  "Xi_c0": {
#   "ctau": 0.00336,
#   "charge": 0.0,
#   "pdg_id": 4132,
#   "mass": 2.47088
#  },
#  "Xi_cbar-": {
#   "ctau": 0.013200000000000002,
#   "charge": -1.0,
#   "pdg_id": -4232,
#   "mass": 2.4678
#  },
#  "Xi_cbar0": {
#   "ctau": 0.00336,
#   "charge": -0.0,
#   "pdg_id": -4132,
#   "mass": 2.47088
#  },
#  "Xi_cc+": {
#   "ctau": 0.010000000000000002,
#   "charge": 1.0,
#   "pdg_id": 4412,
#   "mass": 3.59798
#  },
#  "Xi_cc++": {
#   "ctau": 0.010000000000000002,
#   "charge": 2.0,
#   "pdg_id": 4422,
#   "mass": 3.59798
#  },
#  "Xi_ccbar-": {
#   "ctau": 0.010000000000000002,
#   "charge": -1.0,
#   "pdg_id": -4412,
#   "mass": 3.59798
#  },
#  "Xi_ccbar--": {
#   "ctau": 0.010000000000000002,
#   "charge": -2.0,
#   "pdg_id": -4422,
#   "mass": 3.59798
#  },
#  "Xibar+": {
#   "ctau": 4.91,
#   "charge": 1.0,
#   "pdg_id": -3312,
#   "mass": 1.32171
#  },
#  "Xibar0": {
#   "ctau": 8.709999999999999,
#   "charge": -0.0,
#   "pdg_id": -3322,
#   "mass": 1.31486
#  },
#  "Z''0": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 33,
#   "mass": 900.0
#  },
#  "Z'0": {
#   "ctau": 1.3571047284849102e-15,
#   "charge": 0.0,
#   "pdg_id": 32,
#   "mass": 500.0
#  },
#  "Z0": {
#   "ctau": 7.908262388803243e-15,
#   "charge": 0.0,
#   "pdg_id": 23,
#   "mass": 91.1876
#  },
#  "Z_KK": {
#   "ctau": 8.221956796892439e-17,
#   "charge": 0.0,
#   "pdg_id": 5000023,
#   "mass": 4000.0
#  },
#  "Z_R0": {
#   "ctau": 7.38499113493333e-16,
#   "charge": 0.0,
#   "pdg_id": 9900023,
#   "mass": 1200.0
#  },
#  "Zv": {
#   "ctau": 9.866348156270929e-16,
#   "charge": 0.0,
#   "pdg_id": 4900023,
#   "mass": 1000.0
#  },
#  "a_0(1450)+": {
#   "ctau": 7.446300495298812e-14,
#   "charge": 1.0,
#   "pdg_id": 10211,
#   "mass": 1.474
#  },
#  "a_0(1450)-": {
#   "ctau": 7.446300495298812e-14,
#   "charge": -1.0,
#   "pdg_id": -10211,
#   "mass": 1.474
#  },
#  "a_0(1450)0": {
#   "ctau": 7.446300495298812e-14,
#   "charge": 0.0,
#   "pdg_id": 10111,
#   "mass": 1.474
#  },
#  "a_0(980)+": {
#   "ctau": 3.288782718756976e-13,
#   "charge": 1.0,
#   "pdg_id": 9000211,
#   "mass": 0.9835
#  },
#  "a_0(980)-": {
#   "ctau": 3.288782718756976e-13,
#   "charge": -1.0,
#   "pdg_id": -9000211,
#   "mass": 0.9835
#  },
#  "a_0(980)0": {
#   "ctau": 3.288782718756976e-13,
#   "charge": 0.0,
#   "pdg_id": 9000111,
#   "mass": 0.9835
#  },
#  "a_1(1260)+": {
#   "ctau": 4.6982610267956804e-14,
#   "charge": 1.0,
#   "pdg_id": 20213,
#   "mass": 1.23
#  },
#  "a_1(1260)-": {
#   "ctau": 4.6982610267956804e-14,
#   "charge": -1.0,
#   "pdg_id": -20213,
#   "mass": 1.23
#  },
#  "a_1(1260)0": {
#   "ctau": 4.6982610267956804e-14,
#   "charge": 0.0,
#   "pdg_id": 20113,
#   "mass": 1.23
#  },
#  "a_2+": {
#   "ctau": 1.8441772254712013e-13,
#   "charge": 1.0,
#   "pdg_id": 215,
#   "mass": 1.3183
#  },
#  "a_2-": {
#   "ctau": 1.8441772254712013e-13,
#   "charge": -1.0,
#   "pdg_id": -215,
#   "mass": 1.3183
#  },
#  "a_20": {
#   "ctau": 1.8441772254712013e-13,
#   "charge": 0.0,
#   "pdg_id": 115,
#   "mass": 1.3183
#  },
#  "b": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": 5,
#   "mass": 4.8
#  },
#  "b'": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": 7,
#   "mass": 400.0
#  },
#  "b'bar": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": -7,
#   "mass": 400.0
#  },
#  "b*": {
#   "ctau": 7.608255858690794e-15,
#   "charge": -0.3333333333333333,
#   "pdg_id": 4000005,
#   "mass": 400.0
#  },
#  "b*bar": {
#   "ctau": 7.608255858690794e-15,
#   "charge": 0.3333333333333333,
#   "pdg_id": -4000005,
#   "mass": 400.0
#  },
#  "b_1(1235)+": {
#   "ctau": 1.3896265008832292e-13,
#   "charge": 1.0,
#   "pdg_id": 10213,
#   "mass": 1.2295
#  },
#  "b_1(1235)-": {
#   "ctau": 1.3896265008832292e-13,
#   "charge": -1.0,
#   "pdg_id": -10213,
#   "mass": 1.2295
#  },
#  "b_1(1235)0": {
#   "ctau": 1.3896265008832292e-13,
#   "charge": 0.0,
#   "pdg_id": 10113,
#   "mass": 1.2295
#  },
#  "bb_1": {
#   "ctau": NaN,
#   "charge": -0.6666666666666666,
#   "pdg_id": 5503,
#   "mass": 10.07354
#  },
#  "bb_1bar": {
#   "ctau": NaN,
#   "charge": 0.6666666666666666,
#   "pdg_id": -5503,
#   "mass": 10.07354
#  },
#  "bbar": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": -5,
#   "mass": 4.8
#  },
#  "bbbar[1S0(8)]": {
#   "ctau": 1.9732696312541857e-12,
#   "charge": 0.0,
#   "pdg_id": 9900551,
#   "mass": 9.5
#  },
#  "bbbar[3P0(8)]": {
#   "ctau": 1.9732696312541857e-12,
#   "charge": 0.0,
#   "pdg_id": 9910551,
#   "mass": 9.5
#  },
#  "bbbar[3S1(8)]": {
#   "ctau": 1.9732696312541857e-12,
#   "charge": 0.0,
#   "pdg_id": 9900553,
#   "mass": 9.5
#  },
#  "bc_0": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": 5401,
#   "mass": 6.67143
#  },
#  "bc_0bar": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": -5401,
#   "mass": 6.67143
#  },
#  "bc_1": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": 5403,
#   "mass": 6.67397
#  },
#  "bc_1bar": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": -5403,
#   "mass": 6.67397
#  },
#  "bd_0": {
#   "ctau": NaN,
#   "charge": -0.6666666666666666,
#   "pdg_id": 5101,
#   "mass": 5.38897
#  },
#  "bd_0bar": {
#   "ctau": NaN,
#   "charge": 0.6666666666666666,
#   "pdg_id": -5101,
#   "mass": 5.38897
#  },
#  "bd_1": {
#   "ctau": NaN,
#   "charge": -0.6666666666666666,
#   "pdg_id": 5103,
#   "mass": 5.40145
#  },
#  "bd_1bar": {
#   "ctau": NaN,
#   "charge": 0.6666666666666666,
#   "pdg_id": -5103,
#   "mass": 5.40145
#  },
#  "bs_0": {
#   "ctau": NaN,
#   "charge": -0.6666666666666666,
#   "pdg_id": 5301,
#   "mass": 5.56725
#  },
#  "bs_0bar": {
#   "ctau": NaN,
#   "charge": 0.6666666666666666,
#   "pdg_id": -5301,
#   "mass": 5.56725
#  },
#  "bs_1": {
#   "ctau": NaN,
#   "charge": -0.6666666666666666,
#   "pdg_id": 5303,
#   "mass": 5.57536
#  },
#  "bs_1bar": {
#   "ctau": NaN,
#   "charge": 0.6666666666666666,
#   "pdg_id": -5303,
#   "mass": 5.57536
#  },
#  "bu_0": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": 5201,
#   "mass": 5.38897
#  },
#  "bu_0bar": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": -5201,
#   "mass": 5.38897
#  },
#  "bu_1": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": 5203,
#   "mass": 5.40145
#  },
#  "bu_1bar": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": -5203,
#   "mass": 5.40145
#  },
#  "c": {
#   "ctau": NaN,
#   "charge": 0.6666666666666666,
#   "pdg_id": 4,
#   "mass": 1.5
#  },
#  "c*": {
#   "ctau": 7.598646182728382e-15,
#   "charge": 0.6666666666666666,
#   "pdg_id": 4000004,
#   "mass": 400.0
#  },
#  "c*bar": {
#   "ctau": 7.598646182728382e-15,
#   "charge": -0.6666666666666666,
#   "pdg_id": -4000004,
#   "mass": 400.0
#  },
#  "cbar": {
#   "ctau": NaN,
#   "charge": -0.6666666666666666,
#   "pdg_id": -4,
#   "mass": 1.5
#  },
#  "cc_1": {
#   "ctau": NaN,
#   "charge": 1.3333333333333333,
#   "pdg_id": 4403,
#   "mass": 3.27531
#  },
#  "cc_1bar": {
#   "ctau": NaN,
#   "charge": -1.3333333333333333,
#   "pdg_id": -4403,
#   "mass": 3.27531
#  },
#  "ccbar[1S0(8)]": {
#   "ctau": 1.9732696312541857e-12,
#   "charge": 0.0,
#   "pdg_id": 9900441,
#   "mass": 3.1
#  },
#  "ccbar[3P0(8)]": {
#   "ctau": 1.9732696312541857e-12,
#   "charge": 0.0,
#   "pdg_id": 9910441,
#   "mass": 3.1
#  },
#  "ccbar[3S1(8)]": {
#   "ctau": 1.9732696312541857e-12,
#   "charge": 0.0,
#   "pdg_id": 9900443,
#   "mass": 3.1
#  },
#  "cd_0": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": 4101,
#   "mass": 1.96908
#  },
#  "cd_0bar": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": -4101,
#   "mass": 1.96908
#  },
#  "cd_1": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": 4103,
#   "mass": 2.00808
#  },
#  "cd_1bar": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": -4103,
#   "mass": 2.00808
#  },
#  "chi_0b": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 10551,
#   "mass": 9.8594
#  },
#  "chi_0c": {
#   "ctau": 1.8973746454367167e-12,
#   "charge": 0.0,
#   "pdg_id": 10441,
#   "mass": 3.41475
#  },
#  "chi_1b": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 20553,
#   "mass": 9.8928
#  },
#  "chi_1c": {
#   "ctau": 2.294499571225797e-11,
#   "charge": 0.0,
#   "pdg_id": 20443,
#   "mass": 3.51066
#  },
#  "chi_2b": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 555,
#   "mass": 9.9122
#  },
#  "chi_2c": {
#   "ctau": 9.966008238657502e-12,
#   "charge": 0.0,
#   "pdg_id": 445,
#   "mass": 3.5562
#  },
#  "cs_0": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": 4301,
#   "mass": 2.15432
#  },
#  "cs_0bar": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": -4301,
#   "mass": 2.15432
#  },
#  "cs_1": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": 4303,
#   "mass": 2.17967
#  },
#  "cs_1bar": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": -4303,
#   "mass": 2.17967
#  },
#  "cu_0": {
#   "ctau": NaN,
#   "charge": 1.3333333333333333,
#   "pdg_id": 4201,
#   "mass": 1.96908
#  },
#  "cu_0bar": {
#   "ctau": NaN,
#   "charge": -1.3333333333333333,
#   "pdg_id": -4201,
#   "mass": 1.96908
#  },
#  "cu_1": {
#   "ctau": NaN,
#   "charge": 1.3333333333333333,
#   "pdg_id": 4203,
#   "mass": 2.00808
#  },
#  "cu_1bar": {
#   "ctau": NaN,
#   "charge": -1.3333333333333333,
#   "pdg_id": -4203,
#   "mass": 2.00808
#  },
#  "d": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": 1,
#   "mass": 0.33
#  },
#  "d*": {
#   "ctau": 7.608255858690794e-15,
#   "charge": -0.3333333333333333,
#   "pdg_id": 4000001,
#   "mass": 400.0
#  },
#  "d*bar": {
#   "ctau": 7.608255858690794e-15,
#   "charge": 0.3333333333333333,
#   "pdg_id": -4000001,
#   "mass": 400.0
#  },
#  "dbar": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": -1,
#   "mass": 0.33
#  },
#  "dd_1": {
#   "ctau": NaN,
#   "charge": -0.6666666666666666,
#   "pdg_id": 1103,
#   "mass": 0.77133
#  },
#  "dd_1bar": {
#   "ctau": NaN,
#   "charge": 0.6666666666666666,
#   "pdg_id": -1103,
#   "mass": 0.77133
#  },
#  "e*-": {
#   "ctau": 4.6001250262359784e-14,
#   "charge": -1.0,
#   "pdg_id": 4000011,
#   "mass": 400.0
#  },
#  "e*bar+": {
#   "ctau": 4.6001250262359784e-14,
#   "charge": 1.0,
#   "pdg_id": -4000011,
#   "mass": 400.0
#  },
#  "e+": {
#   "ctau": Infinity,
#   "charge": 1.0,
#   "pdg_id": -11,
#   "mass": 0.000511
#  },
#  "e-": {
#   "ctau": Infinity,
#   "charge": -1.0,
#   "pdg_id": 7211,
#   "mass": 0.000511
#  },
#  "eta": {
#   "ctau": 1.5063126956138822e-08,
#   "charge": 0.0,
#   "pdg_id": 221,
#   "mass": 0.54785
#  },
#  "eta'": {
#   "ctau": 9.866348156270927e-11,
#   "charge": 0.0,
#   "pdg_id": 331,
#   "mass": 0.95778
#  },
#  "eta_b": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 551,
#   "mass": 9.4
#  },
#  "eta_c": {
#   "ctau": 6.644005492438335e-13,
#   "charge": 0.0,
#   "pdg_id": 441,
#   "mass": 2.981
#  },
#  "eta_c(2S)": {
#   "ctau": 1.9732696312541857e-12,
#   "charge": 0.0,
#   "pdg_id": 100441,
#   "mass": 3.6389
#  },
#  "eta_tc0": {
#   "ctau": 2.074723616080523e-13,
#   "charge": 0.0,
#   "pdg_id": 3000331,
#   "mass": 350.0
#  },
#  "f'_2(1525)": {
#   "ctau": 2.703109083909843e-13,
#   "charge": 0.0,
#   "pdg_id": 335,
#   "mass": 1.525
#  },
#  "f_0(1370)": {
#   "ctau": 9.866348156270927e-14,
#   "charge": 0.0,
#   "pdg_id": 10221,
#   "mass": 1.35
#  },
#  "f_0(1710)": {
#   "ctau": 1.4616812083364337e-13,
#   "charge": 0.0,
#   "pdg_id": 10331,
#   "mass": 1.72
#  },
#  "f_0(980)": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 9010221,
#   "mass": 1.0
#  },
#  "f_1(1285)": {
#   "ctau": 8.154006740719776e-13,
#   "charge": 0.0,
#   "pdg_id": 20223,
#   "mass": 1.2821
#  },
#  "f_1(1420)": {
#   "ctau": 3.594298053286312e-13,
#   "charge": 0.0,
#   "pdg_id": 20333,
#   "mass": 1.4264
#  },
#  "f_2": {
#   "ctau": 1.0660559866311107e-13,
#   "charge": 0.0,
#   "pdg_id": 225,
#   "mass": 1.2751
#  },
#  "g": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 21,
#   "mass": 0.0
#  },
#  "gamma": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 22,
#   "mass": 0.0
#  },
#  "gammav": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 4900022,
#   "mass": 0.0
#  },
#  "ggv": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 4900991,
#   "mass": 1.0
#  },
#  "gv": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 4900021,
#   "mass": 0.0
#  },
#  "h0(H_1)": {
#   "ctau": 5.276122008701031e-12,
#   "charge": 0.0,
#   "pdg_id": 25,
#   "mass": 125.0
#  },
#  "h_1(1170)": {
#   "ctau": 5.481304531261626e-14,
#   "charge": 0.0,
#   "pdg_id": 10223,
#   "mass": 1.17
#  },
#  "h_1(1380)": {
#   "ctau": 2.1684281662133907e-13,
#   "charge": 0.0,
#   "pdg_id": 10333,
#   "mass": 1.386
#  },
#  "h_1b": {
#   "ctau": 1.9732696312541857e-12,
#   "charge": 0.0,
#   "pdg_id": 10553,
#   "mass": 9.8986
#  },
#  "h_1c": {
#   "ctau": 1.9732696312541857e-12,
#   "charge": 0.0,
#   "pdg_id": 10443,
#   "mass": 3.52541
#  },
#  "mu*-": {
#   "ctau": 4.6001250262359784e-14,
#   "charge": -1.0,
#   "pdg_id": 4000013,
#   "mass": 400.0
#  },
#  "mu*bar+": {
#   "ctau": 4.6001250262359784e-14,
#   "charge": 1.0,
#   "pdg_id": -4000013,
#   "mass": 400.0
#  },
#  "mu+": {
#   "ctau": 65865.40000000001,
#   "charge": 1.0,
#   "pdg_id": -13,
#   "mass": 0.10566
#  },
#  "mu-": {
#   "ctau": 65865.40000000001,
#   "charge": -1.0,
#   "pdg_id": 7213,
#   "mass": 0.10566
#  },
#  "n0": {
#   "ctau": 26550000000000.0,
#   "charge": 0.0,
#   "pdg_id": 2112,
#   "mass": 0.93957
#  },
#  "n_diffr0": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 9902110,
#   "mass": 0.0
#  },
#  "n_diffrbar0": {
#   "ctau": Infinity,
#   "charge": -0.0,
#   "pdg_id": -9902110,
#   "mass": 0.0
#  },
#  "nbar0": {
#   "ctau": 26550000000000.0,
#   "charge": -0.0,
#   "pdg_id": -2112,
#   "mass": 0.93957
#  },
#  "nu'_tau": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 18,
#   "mass": 400.0
#  },
#  "nu'_taubar": {
#   "ctau": NaN,
#   "charge": -0.0,
#   "pdg_id": -18,
#   "mass": 400.0
#  },
#  "nu*_e0": {
#   "ctau": 4.7081256710588505e-14,
#   "charge": 0.0,
#   "pdg_id": 4000012,
#   "mass": 400.0
#  },
#  "nu*_ebar0": {
#   "ctau": 4.7081256710588505e-14,
#   "charge": -0.0,
#   "pdg_id": -4000012,
#   "mass": 400.0
#  },
#  "nu*_mu0": {
#   "ctau": 4.7081256710588505e-14,
#   "charge": 0.0,
#   "pdg_id": 4000014,
#   "mass": 400.0
#  },
#  "nu*_mubar0": {
#   "ctau": 4.7081256710588505e-14,
#   "charge": -0.0,
#   "pdg_id": -4000014,
#   "mass": 400.0
#  },
#  "nu*_tau0": {
#   "ctau": 4.7081256710588505e-14,
#   "charge": 0.0,
#   "pdg_id": 4000016,
#   "mass": 400.0
#  },
#  "nu*_taubar0": {
#   "ctau": 4.7081256710588505e-14,
#   "charge": -0.0,
#   "pdg_id": -4000016,
#   "mass": 400.0
#  },
#  "nuEv": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": 0.0,
#   "pdg_id": 4900012,
#   "mass": 400.0
#  },
#  "nuEvbar": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": -0.0,
#   "pdg_id": -4900012,
#   "mass": 400.0
#  },
#  "nuMUv": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": 0.0,
#   "pdg_id": 4900014,
#   "mass": 400.0
#  },
#  "nuMUvbar": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": -0.0,
#   "pdg_id": -4900014,
#   "mass": 400.0
#  },
#  "nuTAUv": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": 0.0,
#   "pdg_id": 4900016,
#   "mass": 400.0
#  },
#  "nuTAUvbar": {
#   "ctau": 1.9732696312541852e-14,
#   "charge": -0.0,
#   "pdg_id": -4900016,
#   "mass": 400.0
#  },
#  "nu_Re": {
#   "ctau": 2.0135404400552913e-11,
#   "charge": 0.0,
#   "pdg_id": 9900012,
#   "mass": 500.0
#  },
#  "nu_Rmu": {
#   "ctau": 2.0135404400552913e-11,
#   "charge": 0.0,
#   "pdg_id": 9900014,
#   "mass": 500.0
#  },
#  "nu_Rtau": {
#   "ctau": 2.0342985889218404e-11,
#   "charge": 0.0,
#   "pdg_id": 9900016,
#   "mass": 500.0
#  },
#  "nu_e": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 7212,
#   "mass": 0.0
#  },
#  "nu_ebar": {
#   "ctau": Infinity,
#   "charge": -0.0,
#   "pdg_id": -12,
#   "mass": 0.0
#  },
#  "nu_mu": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 7214,
#   "mass": 0.0
#  },
#  "nu_mubar": {
#   "ctau": Infinity,
#   "charge": -0.0,
#   "pdg_id": -14,
#   "mass": 0.0
#  },
#  "nu_tau": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 7316,
#   "mass": 0.0
#  },
#  "nu_taubar": {
#   "ctau": Infinity,
#   "charge": -0.0,
#   "pdg_id": -16,
#   "mass": 0.0
#  },
#  "omega": {
#   "ctau": 2.324228069792916e-12,
#   "charge": 0.0,
#   "pdg_id": 223,
#   "mass": 0.78265
#  },
#  "omega_di": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 9900220,
#   "mass": 0.0
#  },
#  "omega_tc": {
#   "ctau": 1.0281730050303176e-13,
#   "charge": 0.0,
#   "pdg_id": 3000223,
#   "mass": 210.0
#  },
#  "p+": {
#   "ctau": Infinity,
#   "charge": 1.0,
#   "pdg_id": 2212,
#   "mass": 0.93827
#  },
#  "p_diffr+": {
#   "ctau": Infinity,
#   "charge": 1.0,
#   "pdg_id": 9902210,
#   "mass": 0.0
#  },
#  "p_diffrbar-": {
#   "ctau": Infinity,
#   "charge": -1.0,
#   "pdg_id": -9902210,
#   "mass": 0.0
#  },
#  "pbar-": {
#   "ctau": Infinity,
#   "charge": -1.0,
#   "pdg_id": -2212,
#   "mass": 0.93827
#  },
#  "phi": {
#   "ctau": 4.6320883362774304e-12,
#   "charge": 0.0,
#   "pdg_id": 333,
#   "mass": 1.01946
#  },
#  "phi_diff": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 9900330,
#   "mass": 0.0
#  },
#  "pi'_tc0": {
#   "ctau": 4.3502416914774814e-13,
#   "charge": 0.0,
#   "pdg_id": 3000221,
#   "mass": 110.0
#  },
#  "pi+": {
#   "ctau": 780.45,
#   "charge": 1.0,
#   "pdg_id": 211,
#   "mass": 0.13957
#  },
#  "pi-": {
#   "ctau": 780.45,
#   "charge": -1.0,
#   "pdg_id": -211,
#   "mass": 0.13957
#  },
#  "pi0": {
#   "ctau": 2.55313e-06,
#   "charge": 0.0,
#   "pdg_id": 111,
#   "mass": 0.13498
#  },
#  "pi_22_1_tc": {
#   "ctau": 8.594379927065269e-13,
#   "charge": 0.0,
#   "pdg_id": 3100111,
#   "mass": 125.0
#  },
#  "pi_22_8_tc": {
#   "ctau": 1.0448319555513003e-13,
#   "charge": 0.0,
#   "pdg_id": 3200111,
#   "mass": 250.0
#  },
#  "pi_diffr+": {
#   "ctau": Infinity,
#   "charge": 1.0,
#   "pdg_id": 9900210,
#   "mass": 0.0
#  },
#  "pi_diffr-": {
#   "ctau": Infinity,
#   "charge": -1.0,
#   "pdg_id": -9900210,
#   "mass": 0.0
#  },
#  "pi_tc+": {
#   "ctau": 1.1334116204791415e-12,
#   "charge": 1.0,
#   "pdg_id": 3000211,
#   "mass": 110.0
#  },
#  "pi_tc-": {
#   "ctau": 1.1334116204791415e-12,
#   "charge": -1.0,
#   "pdg_id": -3000211,
#   "mass": 110.0
#  },
#  "pi_tc0": {
#   "ctau": 6.778665857966973e-13,
#   "charge": 0.0,
#   "pdg_id": 3000111,
#   "mass": 110.0
#  },
#  "pivDiag": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 4900111,
#   "mass": 10.0
#  },
#  "pivDn": {
#   "ctau": NaN,
#   "charge": -0.0,
#   "pdg_id": -4900211,
#   "mass": 10.0
#  },
#  "pivUp": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 4900211,
#   "mass": 10.0
#  },
#  "psi(2S)": {
#   "ctau": 6.577565437513952e-11,
#   "charge": 0.0,
#   "pdg_id": 100443,
#   "mass": 3.68611
#  },
#  "psi(3770)": {
#   "ctau": 7.254667761963917e-13,
#   "charge": 0.0,
#   "pdg_id": 30443,
#   "mass": 3.77315
#  },
#  "qv": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 4900101,
#   "mass": 100.0
#  },
#  "qvbar": {
#   "ctau": NaN,
#   "charge": -0.0,
#   "pdg_id": -4900101,
#   "mass": 100.0
#  },
#  "rho(1450)+": {
#   "ctau": 4.9331740781354634e-14,
#   "charge": 1.0,
#   "pdg_id": 100213,
#   "mass": 1.465
#  },
#  "rho(1450)-": {
#   "ctau": 4.9331740781354634e-14,
#   "charge": -1.0,
#   "pdg_id": -100213,
#   "mass": 1.465
#  },
#  "rho(1450)0": {
#   "ctau": 4.9331740781354634e-14,
#   "charge": 0.0,
#   "pdg_id": 100113,
#   "mass": 1.465
#  },
#  "rho+": {
#   "ctau": 1.32345381036498e-13,
#   "charge": 1.0,
#   "pdg_id": 213,
#   "mass": 0.77549
#  },
#  "rho-": {
#   "ctau": 1.32345381036498e-13,
#   "charge": -1.0,
#   "pdg_id": -213,
#   "mass": 0.77549
#  },
#  "rho0": {
#   "ctau": 1.32345381036498e-13,
#   "charge": 0.0,
#   "pdg_id": 113,
#   "mass": 0.77549
#  },
#  "rho_11_tc": {
#   "ctau": 8.480546322056789e-16,
#   "charge": 0.0,
#   "pdg_id": 3100113,
#   "mass": 400.0
#  },
#  "rho_12_tc": {
#   "ctau": 6.892170025267321e-15,
#   "charge": 0.0,
#   "pdg_id": 3200113,
#   "mass": 350.0
#  },
#  "rho_21_tc": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 3300113,
#   "mass": 350.0
#  },
#  "rho_22_tc": {
#   "ctau": 5.704690711714514e-15,
#   "charge": 0.0,
#   "pdg_id": 3400113,
#   "mass": 300.0
#  },
#  "rho_diff0": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 9900110,
#   "mass": 0.0
#  },
#  "rho_tc+": {
#   "ctau": 3.162544484741062e-14,
#   "charge": 1.0,
#   "pdg_id": 3000213,
#   "mass": 210.0
#  },
#  "rho_tc-": {
#   "ctau": 3.162544484741062e-14,
#   "charge": -1.0,
#   "pdg_id": -3000213,
#   "mass": 210.0
#  },
#  "rho_tc0": {
#   "ctau": 2.2717817536889078e-14,
#   "charge": 0.0,
#   "pdg_id": 3000113,
#   "mass": 210.0
#  },
#  "rhovDiag": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 4900113,
#   "mass": 10.0
#  },
#  "rhovDn": {
#   "ctau": NaN,
#   "charge": -0.0,
#   "pdg_id": -4900213,
#   "mass": 10.0
#  },
#  "rhovUp": {
#   "ctau": NaN,
#   "charge": 0.0,
#   "pdg_id": 4900213,
#   "mass": 10.0
#  },
#  "rndmflavg": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 83,
#   "mass": 0.0
#  },
#  "rndmflavgbar": {
#   "ctau": Infinity,
#   "charge": -0.0,
#   "pdg_id": -83,
#   "mass": 0.0
#  },
#  "rndmflavq": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 82,
#   "mass": 0.0
#  },
#  "rndmflavqbar": {
#   "ctau": Infinity,
#   "charge": -0.0,
#   "pdg_id": -82,
#   "mass": 0.0
#  },
#  "s": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": 3,
#   "mass": 0.5
#  },
#  "s*": {
#   "ctau": 7.608255858690794e-15,
#   "charge": -0.3333333333333333,
#   "pdg_id": 4000003,
#   "mass": 400.0
#  },
#  "s*bar": {
#   "ctau": 7.608255858690794e-15,
#   "charge": 0.3333333333333333,
#   "pdg_id": -4000003,
#   "mass": 400.0
#  },
#  "sbar": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": -3,
#   "mass": 0.5
#  },
#  "sd_0": {
#   "ctau": NaN,
#   "charge": -0.6666666666666666,
#   "pdg_id": 3101,
#   "mass": 0.80473
#  },
#  "sd_0bar": {
#   "ctau": NaN,
#   "charge": 0.6666666666666666,
#   "pdg_id": -3101,
#   "mass": 0.80473
#  },
#  "sd_1": {
#   "ctau": NaN,
#   "charge": -0.6666666666666666,
#   "pdg_id": 3103,
#   "mass": 0.92953
#  },
#  "sd_1bar": {
#   "ctau": NaN,
#   "charge": 0.6666666666666666,
#   "pdg_id": -3103,
#   "mass": 0.92953
#  },
#  "specflav": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 81,
#   "mass": 0.0
#  },
#  "ss_1": {
#   "ctau": NaN,
#   "charge": -0.6666666666666666,
#   "pdg_id": 3303,
#   "mass": 1.09361
#  },
#  "ss_1bar": {
#   "ctau": NaN,
#   "charge": 0.6666666666666666,
#   "pdg_id": -3303,
#   "mass": 1.09361
#  },
#  "su_0": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": 3201,
#   "mass": 0.80473
#  },
#  "su_0bar": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": -3201,
#   "mass": 0.80473
#  },
#  "su_1": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": 3203,
#   "mass": 0.92953
#  },
#  "su_1bar": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": -3203,
#   "mass": 0.92953
#  },
#  "system": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 90,
#   "mass": 0.0
#  },
#  "t": {
#   "ctau": 1.4094783080387039e-14,
#   "charge": 0.6666666666666666,
#   "pdg_id": 6,
#   "mass": 171.0
#  },
#  "t'": {
#   "ctau": NaN,
#   "charge": 0.6666666666666666,
#   "pdg_id": 8,
#   "mass": 400.0
#  },
#  "t'bar": {
#   "ctau": NaN,
#   "charge": -0.6666666666666666,
#   "pdg_id": -8,
#   "mass": 400.0
#  },
#  "t*": {
#   "ctau": 7.598646182728382e-15,
#   "charge": 0.6666666666666666,
#   "pdg_id": 4000006,
#   "mass": 400.0
#  },
#  "t*bar": {
#   "ctau": 7.598646182728382e-15,
#   "charge": -0.6666666666666666,
#   "pdg_id": -4000006,
#   "mass": 400.0
#  },
#  "tau'+": {
#   "ctau": NaN,
#   "charge": 1.0,
#   "pdg_id": -17,
#   "mass": 400.0
#  },
#  "tau'-": {
#   "ctau": NaN,
#   "charge": -1.0,
#   "pdg_id": 17,
#   "mass": 400.0
#  },
#  "tau*-": {
#   "ctau": 4.6001250262359784e-14,
#   "charge": -1.0,
#   "pdg_id": 4000015,
#   "mass": 400.0
#  },
#  "tau*bar+": {
#   "ctau": 4.6001250262359784e-14,
#   "charge": 1.0,
#   "pdg_id": -4000015,
#   "mass": 400.0
#  },
#  "tau+": {
#   "ctau": 0.008711000000000002,
#   "charge": 1.0,
#   "pdg_id": -15,
#   "mass": 1.77682
#  },
#  "tau-": {
#   "ctau": 0.008711000000000002,
#   "charge": -1.0,
#   "pdg_id": 15,
#   "mass": 1.77682
#  },
#  "tbar": {
#   "ctau": 1.4094783080387039e-14,
#   "charge": -0.6666666666666666,
#   "pdg_id": -6,
#   "mass": 171.0
#  },
#  "u": {
#   "ctau": NaN,
#   "charge": 0.6666666666666666,
#   "pdg_id": 2,
#   "mass": 0.33
#  },
#  "u*": {
#   "ctau": 7.598646182728382e-15,
#   "charge": 0.6666666666666666,
#   "pdg_id": 4000002,
#   "mass": 400.0
#  },
#  "u*bar": {
#   "ctau": 7.598646182728382e-15,
#   "charge": -0.6666666666666666,
#   "pdg_id": -4000002,
#   "mass": 400.0
#  },
#  "ubar": {
#   "ctau": NaN,
#   "charge": -0.6666666666666666,
#   "pdg_id": -2,
#   "mass": 0.33
#  },
#  "ud_0": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": 2101,
#   "mass": 0.57933
#  },
#  "ud_0bar": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": -2101,
#   "mass": 0.57933
#  },
#  "ud_1": {
#   "ctau": NaN,
#   "charge": 0.3333333333333333,
#   "pdg_id": 2103,
#   "mass": 0.77133
#  },
#  "ud_1bar": {
#   "ctau": NaN,
#   "charge": -0.3333333333333333,
#   "pdg_id": -2103,
#   "mass": 0.77133
#  },
#  "uu_1": {
#   "ctau": NaN,
#   "charge": 1.3333333333333333,
#   "pdg_id": 2203,
#   "mass": 0.77133
#  },
#  "uu_1bar": {
#   "ctau": NaN,
#   "charge": -1.3333333333333333,
#   "pdg_id": -2203,
#   "mass": 0.77133
#  },
#  "void": {
#   "ctau": Infinity,
#   "charge": 0.0,
#   "pdg_id": 0,
#   "mass": 0.0
#  }
# }
