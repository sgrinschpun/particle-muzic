# %%
# %matplotlib inline  
from __future__ import division
import sys, json, math
from particle2 import Particle, ParticleDT
import pypdt
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-c16ac6f22a35> in <module>()
#       2 from __future__ import division
#       3 import sys, json, math
# ----> 4 from particle2 import Particle, ParticleDT
#       5 import pypdt
#       6 import numpy as np
#
# /Users/sgrinschpun/code/particle-muzic/playground/ipynbs/particle2.py in <module>()
#      17
#      18 #ParticleDataTool gives us the decay channels
# ---> 19 from ParticleDataTool import ParticleDataTool as pdt
#      20 pythia = pdt.PYTHIAParticleData(file_path='ParticleData.ppl', use_cache=True)
#      21
#
# ImportError: No module named ParticleDataTool

# %%
tbl = pypdt.ParticleDataTable()

part_dict = {}
for p in tbl:
    part_dict[p.name]= p.id

mass_array = []
mass_dict = {}
for p in tbl: 
    mass_array.append(p.mass)
    mass_dict[p.name]=p.mass
mass_array=np.asarray(mass_array)

def search_mass(mass):
    for name, m in mass_dict.iteritems():
        if m == mass:
            print name

def renormalize_lin(n, range1, range2):
    delta1 = range1[1] - range1[0]
    delta2 = range2[1] - range2[0]
    return (delta2 * (n - range1[0]) / delta1) + range2[0]

# %%
search_mass(max(mass_array))
# Out:
# tbar

# %%
search_mass(min(mass_array))
# Out:
# nu_tau
# g0
# gamma0
# nu_e
# nubar_e
# nubar_mu
# nu_mu
# nubar_tau

# %%
len(mass_array)
# Out:
# 403

# %%
plt.figure(figsize=(40,20))
#plt.subplot(1, 2, 1)
#hist, bin_edges =np.histogram(mass_array, bins=np.linspace(0,100,5))
#plt.bar(bin_edges[:-1], hist, width=0.5)
#plt.xlabel('Mass')
#plt.ylabel('Number of events')
#plt.subplot(1, 2, 2)
hist, bin_edges =np.histogram(mass_array, bins=np.linspace(min(mass_array),max(mass_array),10))
plt.bar(bin_edges[:-1], hist, width=10)
plt.xlabel('Mass')
plt.ylabel('Number of events')
#hist.sum()

# %%
hist
# Out:
# array([397,   0,   0,   0,   3,   0,   1,   0,   2])

# %%
bin_edges
# Out:
# array([  0.        ,  19.24555556,  38.49111111,  57.73666667,
#         76.98222222,  96.22777778, 115.47333333, 134.71888889,
#        153.96444444, 173.21      ])

# %%
def log(a):
    return np.log10(1+a, out=np.zeros_like(a), where=a!=0)

def p3map(n):
    range1 =[0,max(log(mass_array))]
    range2 =[0,1]
    delta1 = range1[1] - range1[0]
    delta2 = range2[1] - range2[0]
    return (delta2 * (n - range1[0]) / delta1) + range2[0]

def convert(x):
    return p3map(log(x))

# %%
plt.figure(figsize=(40,20))
#plt.subplot(1, 2, 1)
hist, bin_edges =np.histogram(log(mass_array), bins=np.linspace(0,max(log(mass_array)),30))
plt.bar(bin_edges[:-1], hist, width=0.1, color='r')
plt.xlabel('Mass')
plt.ylabel('Number of events')
#plt.subplot(1, 2, 2)
hist, bin_edges =np.histogram(p3map(log(mass_array)), bins=np.linspace(0,1,30))
plt.bar(bin_edges[:-1], hist, width=0.05)
plt.xlabel('Mass')
plt.ylabel('Number of events')

# %%
hist, bin_edges =np.histogram(log(mass_array), bins=np.linspace(0,max(log(mass_array)),11))

# %%
hist
# Out:
# array([ 28, 180, 140,  35,  14,   0,   0,   0,   3,   3])

# %%
bin_edges
# Out:
#        5.12150537e-01, 5.12150537e-01, 4.80725379e-01, 4.29752280e-01,
#        4.24064525e-01, 4.14973348e-01, 4.14973348e-01, 8.61838967e-01,
#        8.28627678e-01, 8.01036497e-01, 7.97911924e-01, 7.02344358e-01,
#        5.81676646e-01, 4.34568904e-01, 1.06368606e+00, 4.26511261e-01,
#        3.85606274e-01, 5.52558716e-01, 4.93053544e-01, 4.72503403e-01,
#        4.03977964e-01, 5.39753371e-01, 4.65382851e-01, 4.78604008e-01,
#        4.57818337e-01, 4.34089638e-01, 4.60897843e-01, 4.31363764e-01,
#        4.34089638e-01, 1.07521838e+00, 3.48304863e-01, 4.83587297e-01,
#        4.43419462e-01, 5.59680446e-01, 3.84819184e-01, 2.76843081e-01,
#        1.74256694e-01, 4.03977964e-01, 4.65382851e-01, 4.60897843e-01,
#        4.65382851e-01, 1.05136479e+00, 6.78803263e-01, 3.48304863e-01,
#        3.58315640e-01, 3.61727836e-01, 3.91816924e-01, 5.61804753e-01,
#        5.53361074e-01, 4.76396827e-01, 4.29558499e-01, 3.65169635e-01,
#        5.55366553e-01, 2.49261968e-01, 5.67410762e-02, 5.48401704e-01,
#        5.20837113e-01, 1.75399021e-01, 4.66867620e-01, 4.59392488e-01,
#        3.48694190e-01, 4.19955748e-01, 3.93399695e-01, 4.28944290e-01,
#        5.20876382e-01, 1.03739861e+00, 4.27323786e-01, 1.04780816e+00,
#        4.49632650e-01, 2.87414740e-01, 4.69822016e-01, 3.80753771e-01,
#        4.49632650e-01, 1.05519479e+00, 3.84962397e-01, 3.61727836e-01,
#        3.91816924e-01, 5.40070323e-01, 5.78856876e-01, 3.60593414e-01,
#        3.84711743e-01, 5.46346446e-01, 4.78566496e-01, 4.48706320e-01,
#        4.26868960e-01, 5.78536067e-01, 5.46234106e-01, 5.38184001e-01,
#        3.71067862e-01, 4.17803723e-01, 4.42949870e-01, 3.56408327e-01,
#        3.85606274e-01, 5.03790683e-01, 4.00537989e-01, 4.31363764e-01,
#        4.28944290e-01, 4.31363764e-01, 4.69822016e-01, 2.03640226e-03,
#        5.39013335e-01, 1.05047643e+00, 3.82737266e-01, 6.54240093e-01,
#        3.82737266e-01, 3.48207477e-01, 5.16728351e-01, 4.26868960e-01,
#        1.91054437e+00, 3.93750640e-01, 4.28134794e-01, 3.36459734e-01,
#        0.00000000e+00, 4.43553985e-01, 0.00000000e+00, 4.36209597e-02,
#        0.00000000e+00, 2.21867340e-04, 2.24107308e+00, 7.14329760e-01,
#        3.56025857e-01, 3.98105541e-02, 9.54398406e-04])

# %%
def mass_map(x):
    return  math.log10(1+x) / math.log10(1+173.21)

# %%
map_mass(0)
# Out:
# 0.0

# %%
ParticleDT('e-').mass
# Out:
# 0.0005109989461

# %%
log(ParticleDT('e-').mass)
# Out:
# array(0.00022187)

# %%
ParticleDT('dbar').mass
# Out:
# 0.0047

# %%
ParticleDT('n0').mass
# Out:
# 0.939565413

# %%
ParticleDT('p+').mass
# Out:
# 0.938272081

# %%
for x in range(-234.8, 12.2):
    print x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-f13e6e980f06> in <module>()
# ----> 1 for x in range(-234.8, 12.2):
#       2     print x
#
# TypeError: range() integer end argument expected, got float.
