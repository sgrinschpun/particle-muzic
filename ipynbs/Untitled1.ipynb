# %%
import pypdt

# %%
class P(object):

    def __init__(self,x):
        self.__set_x(x)

    @property
    def x(self):
        print "I'm the 'x' property."
        return self.__x

    def __set_x(self, x):
        print "Set!"
        if x < 0:
            self.__x = 0
        elif x > 1000:
            self.__x = 1000
        else:
            self.__x = x

# %%
a = P(20)
# Out:
# Set!

# %%
a.x
# Out:
# I'm the 'x' property.
# 20

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, '../')
from particle import Particle, ParticleDT
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-d969075e17b8> in <module>()
#       1 import sys
#       2 sys.path.insert(0, '../')
# ----> 3 from particle import Particle, ParticleDT
#
# ImportError: cannot import name Particle

# %%
p = ParticleDT('pi+')

# %%
p.timetodecay
# Out:
# 3.15

# %%
p.decay
# Out:
# ['mu+', 'nu_mu']

# %%
Z= ParticleDT('Z0')

# %%
Z.composition
# Out:
# []

# %%
Z.timetodecay
# Out:
# 0.19

# %%
Z.decay
# Out:
# ['dbar', 'dbar']

# %%
Z.getDecayTreeAll()
# Out:
# -Channel 0 : 0.153995
# --dbar
# ---Stable
# --dbar
# ---Stable
# -Channel 1 : 0.153984
# --sbar
# ---Stable
# --sbar
# ---Stable
# -Channel 2 : 0.152272
# --bbar
# ---Stable
# --bbar
# ---Stable
# -Channel 3 : 0.11942
# --ubar
# ---Stable
# --ubar
# ---Stable
# -Channel 4 : 0.119259
# --cbar
# ---Stable
# --cbar
# ---Stable
# -Channel 5 : 0.066806
# --nu_e
# ---Stable
# --nubar_e
# ---Stable
# -Channel 6 : 0.066806
# --nu_mu
# ---Stable
# --nubar_mu
# ---Stable
# -Channel 7 : 0.066806
# --nu_tau
# ---Stable
# --nubar_tau
# ---Stable
# -Channel 8 : 0.033576
# --e-
# ---Stable
# --e+
# ---Stable
# -Channel 9 : 0.033576
# --mu-
# --Channel 0 : 1.0
# ---nubar_e
# ----Stable
# ---e-
# ----Stable
# ---nu_mu
# ----Stable
# --mu+
# --Channel 0 : 1.0
# ---nu_e
# ----Stable
# ---e+
# ----Stable
# ---nubar_mu
# ----Stable
# -Channel 10 : 0.0335
# --tau-
# --Channel 0 : 0.25489
# ---nu_tau
# ----Stable
# ---pi0
# ---Channel 0 : 0.98799
# ----gamma0
# -----Stable
# ----gamma0
# -----Stable
# ...

# %%
dbar = ParticleDT('dbar')

# %%
dbar.timetodecay
# Out:
# 'stable'
